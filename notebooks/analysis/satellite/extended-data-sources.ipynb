# %% [markdown]
# # Extending the number of data sources from tidal gauge stations and satellite data
#
# This notebooks explores different sources for extending the number of data sources for the sea level monitor. These extra sources can be used for getting a grip on regional differences in the speed with which the sea level rises.
#
# The primary source of the tidal data is the PSMSL website. This website receives the tide gauge data from Rijkswaterstaat. The notebook get-data can be used to obtain the data.

# %%
# Standard Python packages
import io

# Python packages that need to be installed using pip or anaconda:
# For computations
import pandas
import numpy as np

# For GIS related function
import pyproj
from shapely.geometry import LineString, Point

# For loading netcdf
import netCDF4

# For plotting
import matplotlib.pyplot as plt
import bokeh.palettes
import bokeh.plotting
from bokeh.models import HoverTool

# Initialize modules for the jupyter notebook format
from nbformat import current
# %matplotlib inline
bokeh.io.output_notebook()

# Disable pandas warnings
pandas.options.mode.chained_assignment = None
# Out:
# C:\Anaconda3\lib\site-packages\nbformat\current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="deb93977-293e-4f26-99b6-b9e055bcfd19">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Define a function to read from functions from other notebooks

# %%
def execute_notebook(nbfile):
    """Function to run other notebook in this notebook"""
    with io.open(nbfile,encoding="utf8") as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)

# %% [markdown]
# A set of functions to get data is defined in the notebook 'get-data.py' We import this here.

# %%
execute_notebook('get-data.ipynb')

# %% [markdown]
# ## Extended station collection
#
# Currently the methods of the sea level monitor are applief on data of six tidal stations along the Dutch coast. For these stations the data is available via PSMSL, and the data are converted to RLR with NAP correction. There is however more data available from PSMSL, partly in RLR, and partly metric data (NAP). In the next section of this notebook, this data is retireved and compared to the 'official' data in the sea level monitor.

# %%
rlr_stations = [
    'Vlissingen', 
    'Hoek van Holland', 
    'Den Helder', 
    'Delfzijl', 
    'Harlingen', 
    'IJmuiden'
]

met_stations = rlr_stations + [
    'Maassluis',
    'Roompot Buiten',
    'West-Terschelling'
]

# The alpha values are the dominant wind direction for the coast stations.
alphas = {
    "delfzijl": 117,
    "harlingen": 108,
    "den helder": 107,
    "ijmuiden": 110,
    "hoek van holland": 117,
    "vlissingen": 118,
    "maassluis": 117,
    "roompot buiten": 117,
    "west-terschelling": 107,
}

rlr_data = get_station_data(dataset_name='rlr_monthly', coastline_code=150, names=rlr_stations, alphas=alphas)
met_data = get_station_data(dataset_name='met_monthly', coastline_code=150, names=met_stations, alphas=alphas)
# Out:
# found point 52.3799 3.75
# rlr_monthly 20 rlr
# rlr_monthly 20 rlr
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-470b9e36842d> in <module>()
#      27 }
#      28
# ---> 29 rlr_data = get_station_data(dataset_name='rlr_monthly', coastline_code=150, names=rlr_stations, alphas=alphas)
#      30 met_data = get_station_data(dataset_name='met_monthly', coastline_code=150, alphas=alphas)
#
# <ipython-input-3-ee7f75d94a51> in get_station_data(dataset_name, coastline_code, names, include_wind, alphas)
#      18     f = functools.partial(get_url, dataset=dataset_name)
#      19     # compute the url for each station
# ---> 20     selected_stations['url'] = selected_stations.apply(f, axis=1)
#      21
#      22     selected_stations['data'] = [get_data(zf, wind_df, station, dataset=dataset_name, alpha=alphas)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-3-717706ef9964> in get_url(station, dataset)
#       7         typetag=dataset.split('_')[0]
#       8     )
# ----> 9     url = names['url'].format(**info)
#      10     return url
#
# TypeError: ('list indices must be integers or slices, not str', 'occurred at index 20')

# %% [markdown]
# Time series analysis of the gauge data, where the sea level y is described by a linear regression model with a trend, 18.6-year nodal cycle and the wind.

# %%
# Comments

colors = bokeh.palettes.Category20_15

stationsets = [
    [station.upper() for station in rlr_stations],
    [station.upper() for station in met_stations],
    met_data['name'].squeeze().tolist()
]

for stationset in stationsets:
    fig = bokeh.plotting.figure(
        x_range=(1840, 2020),
        plot_width=950,
        plot_height=450
    )
    
    for color, name in zip(colors, stationset):
        # Check if station is available in rlr set, otherwise use metric set
        if name in rlr_data['name'].values:
            station = rlr_data.set_index('name').loc[name]
            linestyle = 'solid'
        else:
            station = met_data.set_index('name').loc[name]
            linestyle = 'dashed'
        
        # Some series contain -9999, we set these values to nan
        station['data'].loc[(station['data']['height'] < -9000), 'height'] = np.nan
        
        # Select the data after 1890
        df = station['data'].loc[station['data'].year >= 1890]
        
        fit, names = linear_model(df, with_wind=False, with_season=False)
        
        fig.line(
            fit.model.exog[:, 1] + 1970,
            fit.predict() / 1e3,
            line_width=3,
            alpha=0.8,
            legend=station.name,
            color=color,
            line_dash=linestyle
        )

    fig.legend.location = "top_left"
    fig.yaxis.axis_label = 'Sea water level (m+NAP)'
    fig.xaxis.axis_label = 'Year'
    
    bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b0955b72-c11d-44e8-997a-8359debc4ec3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b0955b72-c11d-44e8-997a-8359debc4ec3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b0955b72-c11d-44e8-997a-8359debc4ec3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b0955b72-c11d-44e8-997a-8359debc4ec3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ee119500-bf87-4e27-a233-d286ff5274d4":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"59a89d4f-1081-428d-88a6-6c4b6bd4c9c2","type":"Line"},{"attributes":{"label":{"value":"IJMUIDEN"},"renderers":[{"id":"e026760c-5ce4-4db9-94aa-1198bee53e25","type":"GlyphRenderer"}]},"id":"d53729bd-b12d-4f4c-a284-36a3246d7e6e","type":"LegendItem"},{"attributes":{"data_source":{"id":"1eb3a64c-ace9-43b6-91b8-703eeacedb2c","type":"ColumnDataSource"},"glyph":{"id":"fbc47935-e42b-42ad-bf07-bf993809cdce","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"59a89d4f-1081-428d-88a6-6c4b6bd4c9c2","type":"Line"},"selection_glyph":null},"id":"eb9fdc30-d7b8-4b37-9088-ff6460d77b58","type":"GlyphRenderer"},{"attributes":{"label":{"value":"HOEK VAN HOLLAND"},"renderers":[{"id":"eb9fdc30-d7b8-4b37-9088-ff6460d77b58","type":"GlyphRenderer"}]},"id":"291de856-ef39-4aac-9325-58fdefb17251","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"62a2964f-d380-43b2-ac33-e486e47915d3","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[
type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e3a6ff3b-e137-49a4-be24-d9f753c50242","type":"Line"},{"attributes":{"label":{"value":"VLISSINGEN"},"renderers":[{"id":"8c74b3ea-c2d1-4485-bbcb-6185e5c898d9","type":"GlyphRenderer"}]},"id":"c60233a0-406e-432a-aead-c1ea3c1c6bdd","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[432]},"y":{"__ndarray__":"...","dtype":"float64","shape":[432]}}},"id":"464abdad-f4b0-4158-b377-add443401d19","type":"ColumnDataSource"},{"attributes":{"label":{"value":"DELFZIJL"},"renderers":[{"id":"655476a9-599f-4a6b-a5db-846c87dcaed2","type":"GlyphRenderer"}]},"id":"755808eb-e5f2-479a-98a5-916d21792a17","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#2ca02c"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5baa7cd-5846-4da0-b3a9-e6423e90daff","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1c82cd2-7057-4737-9758-1a3961088f7d","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e587852-e36f-45bb-90b4-d0568e860a27","type":"Line"},{"attributes":{"data_source":{"id":"1853fb69-e7c2-4cfa-87a3-c62f6e40dc4c","type":"ColumnDataSource"},"glyph":{"id":"ff2dd1da-c3e3-4332-92b0-f846775d7479","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"36d40aea-1f55-4d73-997f-489acb447504","type":"Line"},"selection_glyph":null},"id":"8ab0ea28-90b6-4a39-adde-81ba2be598ba","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"aab2bd17-fe94-4fae-ade5-090a74f37c08","type":"ColumnDataSource"},"glyph":{"id":"7499f494-586c-43ad-8b5c-48f34281a3f3","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c1c82cd2-7057-4737-9758-1a3961088f7d","type":"Line"},"selection_glyph":null},"id":"2601b094-c9b9-4833-95b7-7fb1cab2edad","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"cad64a81-f74d-4f6c-8bf7-8b816ef32e87","type":"ColumnDataSource"},"glyph":{"id":"a5baa7cd-5846-4da0-b3a9-e6423e90daff","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e3a6ff3b-e137-49a4-be24-d9f753c50242","type":"Line"},"selection_glyph":null},"id":"655476a9-599f-4a6b-a5db-846c87dcaed2","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#ffbb78"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7499f494-586c-43ad-8b5c-48f34281a3f3","type":"Line"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#d62728"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff2dd1da-c3e3-4332-92b0-f846775d7479","type":"Line"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#9467bd"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c7dfd97-cfbc-4dca-bc7e-ad90b0d9eb15","type":"Line"},{"attributes":{"label":{"value":"HARLINGEN"},"renderers":[{"id":"7cd39dd6-8400-4da3-8505-41386d7fa860","type":"GlyphRenderer"}]},"id":"ec47c9d3-f071-4cc4-a0ab-0b2c0e69c448","type":"LegendItem"},{"attributes":{"data_source":{"id":"2d8df1c1-135d-4900-a266-43980fbe9148","type":"ColumnDataSource"},"glyph":{"id":"7b432fac-39e4-4504-98e ...

# %% [markdown]
# The top figure contains the fitted sea level trends for the 6 stations that are currently used in the sea level monitor. All series are part of the RLR monthly dataset from PSMSL.
#
# The second figure adds 3 other stations that are also present in the RLR monlthy set from PSMSL. Note that Roomput-Buiten is a very short series, since the station is installed after constructing the Eastern Scheldt storm surge barrier. The standard error around this trend is therefor larger than around the other stations, which is discussed later.
#
# The last figure contains another 6 extra stations, that are in the metric monthly dataset (the dashes lines). The quality of this data is worse, such that PSMSL advices: "in general we highly recommend that you do not use these records". For this exploratory study we do use the data, but keep the advice in mind. The trends from these stations are visually less consistent than the first 6 or 9 trends. Partly due to the shorter series (Frederikse et al. (2016) says at least a 60 year record is needed to detect a 2 mm/year trend), but likely also due to to the worse data quality of the metric monthly data set.

# %% [markdown]
# ## Differences along the Dutch coast
#
# In the next step, the linear model will be used to determine regional differences along the Dutch coast. To do so, every station along the dutch coast is projects on a line along the coast. The coefficient of the linear trend component, as well as the standard error in this coefficient are used to show the speed of the sea level rise along the coast.

# %%
crds = [
    (12000, 377000),
    (12000, 378000),
    (20407, 397159),
    (87784, 468350),
    (111514, 554797),
    (189909, 600139),
    (263643, 607342),
    (264643, 607342)
]
    
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

kustlijn = LineString(crds)

# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'met', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=met_data['name'].values.tolist())

for station_data, tag in zip([rlr_data, met_data], ['rlr', 'met']):
    for name, station in station_data.iterrows():
        # Select the data from 1890 till now
        df = station['data'].loc[station['data'].year >= 1890]
        # Fit the linear model with wind
        fit, names = linear_model(df, with_wind=False, with_season=False)
        # Get the summary
        smry = fit.summary2(xname=names)
        # Determine the coefficient and standard error from the tables, and add to dataframe
        trend_values.loc[station['name'], (tag, 'coeff')] = float(smry.tables[1].values[1, 0])
        trend_values.loc[station['name'], (tag, 'stderr')] = float(smry.tables[1].values[1, 1])
        station_data.loc[name, 'trend_coef'] = float(smry.tables[1].values[1, 0])
        station_data.loc[name, 'trend_stderr'] = float(smry.tables[1].values[1, 1])

        # Project the station on the coast line, to determine the projected distance
        station_data.loc[name, 'proj_distance'] = kustlijn.project(
            Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
        )

    # Sort the station data by projected distance for plotting
    station_data.sort_values(by='proj_distance', inplace=True)

# %%
names = ['RLR6', 'RLR9', 'Metric']

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'green', 'orange']
source = {}

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    station_data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    station_data = station_data.set_index('name').loc[stationset]
    station_data.sort_values(by='proj_distance', inplace=True)
    
    dist = station_data['proj_distance'].values
    
    source[name] = station_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance']]
    source[name]['proj_distance'] /= 1000
    source[name]['dataset'] = name
    
    # Add

    # Draw the sea level trend
    fig.line(dist / 1000, station_data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = station_data['trend_coef'].values - station_data['trend_stderr'].values
    upper = station_data['trend_coef'].values + station_data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]] / 1000,
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2, 
        line_alpha=0.0
    )


fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b0c0ddd5-6ad6-4efd-9ebf-0faad43e013b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b0c0ddd5-6ad6-4efd-9ebf-0faad43e013b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b0c0ddd5-6ad6-4efd-9ebf-0faad43e013b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b0c0ddd5-6ad6-4efd-9ebf-0faad43e013b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d2fc6ebf-57c8-4504-9e93-8902e997abc2":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"eb97e8c4-815f-4262-8486-1c503e183bf0","subtype":"Figure","type":"Plot"},"tooltips":[["station","@name"],["dataset","@dataset"],["(lon,lat)","(@lon, @lat)"],["coef","@trend_coef"],["stderr","@trend_stderr"]]},"id":"94d74bdd-92bc-4238-8210-f1f729988870","type":"HoverTool"},{"attributes":{"below":[{"id":"596ff1b9-e936-4123-ae42-b5d198768256","type":"LinearAxis"}],"left":[{"id":"f4e668e2-ed53-41b7-a80f-de556f4bf7c8","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"596ff1b9-e936-4123-ae42-b5d198768256","type":"LinearAxis"},{"id":"1cec3666-5713-41cf-924f-32e6cb70ff1f","type":"Grid"},{"id":"f4e668e2-ed53-41b7-a80f-de556f4bf7c8","type":"LinearAxis"},{"id":"0daba29d-b9ce-47d1-b9fe-f0f37389dde5","type":"Grid"},{"id":"dd5198cf-8616-450b-ac7e-79ea4891e039","type":"BoxAnnotation"},{"id":"f954dbdc-4b17-47f6-b93a-7e56555f9988","type":"Legend"},{"id":"af597760-2191-4602-89c4-8aca22d90f17","type":"GlyphRenderer"},{"id":"851fcd52-9bab-4356-824a-4166a5e9b179","type":"GlyphRenderer"},{"id":"629c3f57-4470-428a-83b9-0fc8bce0842c","type":"GlyphRenderer"},{"id":"5157109c-2bde-4d34-a222-911cfda205fe","type":"GlyphRenderer"},{"id":"4fe60d8a-8de1-4154-ae49-3dd82ec62ee1","type":"GlyphRenderer"},{"id":"e9837c05-2aa0-42c4-b81e-6a16072c4870","type":"GlyphRenderer"},{"id":"b1c4b8a1-7e61-417a-af56-f94b3039443c","type":"GlyphRenderer"},{"id":"668d46aa-9c23-4ca9-8af6-ee23bc0e2bb2","type":"GlyphRenderer"},{"id":"1bd01cf2-0816-4f6e-83e3-1c23ec83ee38","type":"GlyphRenderer"}],"title":{"id":"479f4c92-442e-44c3-a104-4d3b49352952","type":"Title"},"tool_events":{"id":"0ca8a754-f159-4993-bee8-c9836150bf9d","type":"ToolEvents"},"toolbar":{"id":"e9a64791-0377-44dc-a264-881b71bac04a","type":"Toolbar"},"x_range":{"id":"3a52d62e-0b40-4156-bdac-6dd104f8bd3d","type":"DataRange1d"},"y_range":{"id":"705259b6-82b8-4d1e-a213-9e1bdcd5045e","type":"DataRange1d"}},"id":"eb97e8c4-815f-4262-8486-1c503e183bf0","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"5157109c-2bde-4d34-a222-911cfda205fe","type":"GlyphRenderer"}]},"id":"761698d7-2061-4e11-8e21-2a3689e44bfd","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"65788f42-f6fc-46f6-b625-1f8bf28c376a","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDiheeF9CZWQFKOPFZu22JATJd7+Y8FakCuH98rdTZwQJNak0K+9XZAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh/","dtype":"float64","shape":[9]},"y":{"__ndarray__":"RrC4P6h2AUD+b2kFSBwDQKabekZjNAFAP0VYpJV0+D8h5xeqZcL1P3MB2O8x7P8/AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh/","dtype":"float64","shape":[9]}}},"id":"c9b46ca6-037a-4bec-a0f2-3660fa5a0a18","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"40d4bf0d-ca2f-4b92-92e0-d7b81d3930d2","type":"ColumnDataSource"},"glyph":{"id":"643941cf-e033-4135-a819-59b1090cdbaf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"50128cd9-35a7-48dd-ae76-2191e0addcd4","type":"Circle"},"selection_glyph":null},"id":"4fe60d8a-8de1-4154-ae49-3dd82ec62ee1","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"eb97e8c4-815f-4262-8486-1c503e183bf0","subtype":"Figure","type":"Plot"}},"id":"ef99885b-f280-4160-b432-b8c47b36494a","type":"HelpTool"},{"attributes":{},"id":"c3122e56-288a-4c92-b442-0fd7fa936f2f","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"green"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"bbcba651-083b-4b1d-9905-95767c35c88c","type":"Line"},{"attributes":{"plot":{"id":"eb97e8c4-815f-4262-8486-1c503e183bf0","subtype":"Figure","type":"Plot"}},"id":"f1e3ea32-a2b1-47f3-8d62-ca31b813588b","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"fiel ...

# %%
names = ['RLR6', 'RLR9', 'Metric']
fig = bokeh.plotting.figure(x_range=(1885, 2020), plot_width=900, plot_height=400)
colors = ['blue', 'green', 'orange']

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    data = data.set_index('name').loc[stationset]
    
    # compute the mean for metric data
    grouped = pandas.concat(data['data'].dropna().tolist()).reset_index()[['year', 't', 'height', 'u', 'v', 'u2', 'v2']].groupby(['year', 't'])
    mean = grouped.mean().reset_index()
    # filter out non-trusted part (before NAP)
    mean = mean[mean['year'] >= 1890].copy()
    linear_fit, names = linear_model(mean, with_wind=False, with_season=False)

    # Draw the sea level trend
    fig.line(
        linear_fit.model.exog[:, 1] + 1970, 
        linear_fit.predict() / 1000.,
        line_width=3, 
        legend=name, 
        color=color,
        alpha=0.5
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'year'
bokeh.io.show(fig)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # This is added back by InteractiveShellApp.init_path()
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"882a4eea-8427-47ab-82cd-a7bb6a0a5f4b","subtype":"Figure","type":"Plot"}},"id":"e1ca9328-0246-4830-8794-a5ae78db78db","type":"ResetTool"},{"attributes":{},"id":"3c51c0bb-b4ee-45bc-bbdc-f55216fbdded","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"882a4eea-8427-47ab-82cd-a7bb6a0a5f4b","subtype":"Figure","type":"Plot"}},"id":"d4455b63-a3dd-4a5f-b22e-d26cd09f2603","type":"HelpTool"},{"attributes":{"data_source":{"id":"3806e3da-175d-412c-8d60-dcbacab7334c","type":"ColumnDataSource"},"glyph":{"id":"b50d2449-c528-46df-8820-5c7aea3054ee","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"36d9edeb-1471-45a7-ad92-c893e8843bbe","type":"Line"},"selection_glyph":null},"id":"7beff818-0033-48d2-b359-7c371033d75b","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_col ...

# %% [markdown]
# First we compare the effects of adding the three extra stations for which the RLR data can be retrieved at PSMSL. The trends show a that adding the three stations gives higher values around 1900 and equal values around 2000. These differences can be explained by viewing the trends of the 3 extra stations. The addition of West-Terschelling and Roompot-Buiten gives lower values in the more recent part of the trend, while adding Maassluis raises the trend over the full range.
#
# We also compare the rlr data to the metric stations. The trend does not differ considerably from the RLR trends. However, as we saw before, many of the metric stations have a shorter time range for which the data are available. Also some of the 'metric stations' are located at a location not directly at the coast, but for example inside the Eastern Scheldt. The quality if these data is thus worse than the data of the rlr stations.
#
# The trends shown in the following table show that the uncertainty around the metric data is larger, while there is no clear added value in using the extra dataset.

# %%
trend_values.dropna(how='all', axis=1)
# Out:
#                        rlr                 met
#                      coeff     stderr    coeff     stderr
# MAASSLUIS              NaN        NaN  1.65427  0.0692792
# VLISSINGEN         2.18294   0.060013   2.0556  0.0600485
# HOEK VAN HOLLAND   2.38881  0.0671181  2.26996  0.0671868
# DEN HELDER         1.52846  0.0793838  1.45631  0.0793543
# DELFZIJL           1.99516  0.0897969  1.96121  0.0897592
# HARLINGEN          1.35996  0.0920711  1.33025  0.0920071
# IJMUIDEN           2.15058  0.0751801  2.06145  0.0752571
# WEST-TERSCHELLING      NaN        NaN  1.06176   0.131708
# ROOMPOT BUITEN         NaN        NaN  1.34938   0.442774

# %% [markdown]
# ## Satellite data
#
# Next to the data from the tidal stations, there is also sea level data available from satellite observations. In this section of the notebook, we explore these data and compare them to the data from the tidal stations.

# %% [markdown]
# Now we load the satellite data from the netCDF4 file. First de latitude en longitude (axes) of the data are loaded, after which we use the data around the Dutch coast.

# %%
# Import sea level data (USER DEFINED LOCATION)
ds = netCDF4.Dataset(r"d:\Documents\2695.50 Zeespiegelstijging 2018\Data\dt_global_merged_msla_h_merged.nc")

# Get longitude and latitude
lon = ds.variables['lon'][:]
lat = ds.variables['lat'][:]

# Determine relevant part
lon_selection = lon[(lon > 2) * (lon < 7)]
lat_selection = lat[(lat > 51) * (lat < 54.5)]

# Download sea level averages for relevant part
sla = ds.variables['sla'][:, np.in1d(lat, lat_selection), np.in1d(lon, lon_selection)]

# Get the time stamps of the 
time = netCDF4.num2date(ds.variables['time'][:], ds.variables['time'].units)

# %% [markdown]
# We apply the linear model of the sea level data on the data:

# %%
# Load coorindate systems for transformation
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

# Empty list for appending satellite data per coordinate
satellite_data = []

# Loop trough points in relevant range
years = [time[i].year + time[i].month / 12. for i in range(len(time))]
coeff = np.zeros((len(lat_selection), len(lon_selection)))
error = np.zeros_like(coeff)

for i, x in enumerate(lon_selection):
    for j, y in enumerate(lat_selection):
        # Add data
        data = pandas.DataFrame(columns=['year', 'height'])
        data['year'] = years
        data['height'] = sla[:, j, i]
        
        # Skip the coordinate if it is masked
        if any(sla[:, j, i].mask):
            coeff[j, i] = np.nan
            error[j, i] = np.nan
            continue            
        
        # Fit model
        fit, names = linear_model(data, with_wind=False, with_season=False)
        smry = fit.summary2(xname=names)
        
        # Add to list
        trend_coef = float(smry.tables[1].values[1, 0])
        trend_stderr = float(smry.tables[1].values[1, 1])
        satellite_data.append([x, y, trend_coef, trend_stderr, data])
        
        # Add to 2d-arrays
        coeff[j, i] = trend_coef
        error[j, i] = trend_stderr
        
satellite_data = pandas.DataFrame(
    satellite_data,
    columns=['lon', 'lat', 'trend_coef', 'trend_stderr', 'data']
)

# %%
xy = np.loadtxt(r'landboundary.txt')
fig, ax = plt.subplots(figsize=(16/2.54, 13/2.54))

xy = pyproj.transform(RD, WGS84, *xy.T)

ax.plot(*xy, color='0.9', lw=1.0)
ax.plot(*rlr_data[['lon', 'lat']].values.T, marker='.', color='C3', ls='', ms=7, label='Getijdestations')
ax.legend(fancybox=False, loc='lower right', fontsize=8)

lon_step = lon_selection[1] - lon_selection[0]
lat_step = lat_selection[1] - lat_selection[0]

ws = (min(lon_selection) - 0.5 * lon_step, min(lat_selection) - 0.5 * lat_step)
en = (max(lon_selection) + 0.5 * lon_step, max(lat_selection) + 0.5 * lat_step)
im = ax.imshow(
    coeff*1000,
    extent=(ws[0], en[0], ws[1], en[1]),
    origin='lower',
    aspect=1.5
)
ax.set_xlabel('Longitude', fontsize=8)
ax.set_ylabel('Latitude', fontsize=8)

cb = plt.colorbar(im)
cb.set_label('Sea level rise [mm/year]', fontsize=8)

fig.savefig(r"d:\Documents\2695.50 Zeespiegelstijging 2018\Rapportage\Rapportage 2018\figures\slr_satellite.pdf")

# %% [markdown]
# We compare this data to the tidal gauge data. To do so, we interpolate the coastline on which we projected the gauges earlier on in the satellite data. Note that for this interpolation the NaN values are filled with the mean of the values in the researched area. This can affect the result for locations close to the white parts in the figure above.

# %%
from scipy.interpolate import interp2d

# Fill copies of the 2d-arrays with average values at the position of the NaN's
coeff_notnull = coeff.copy()
coeff_notnull[np.isnan(coeff_notnull)] = np.nanmean(coeff)
error_notnull = error.copy()
error_notnull[np.isnan(error_notnull)] = np.nanmean(error)

# Define interpolation function
f_coeff = interp2d(lon_selection, lat_selection, coeff_notnull, kind='linear')
f_error = interp2d(lon_selection, lat_selection, error_notnull, kind='linear')

# Define a grid for plotting
dist = np.linspace(0, kustlijn.length, 200)

# Interpolate coordinaties along the coastline
xy = np.vstack([pyproj.transform(RD, WGS84, *kustlijn.interpolate(i).coords[0]) for i in dist])
z_coeff = np.array([f_coeff(x, y)[0] for x, y in xy]) * 1000
z_error = np.array([f_error(x, y)[0] for x, y in xy]) * 1000

# Draw the sea level trend
fig = bokeh.plotting.figure(
    x_range=(0, max(dist)/1000),
    y_range=(0, 5.0),
    plot_width=900,
    plot_height=400
)

fig.line(
    dist/1000,
    z_coeff, 
    line_width=3,
    legend='coefficient of linear trend', 
    color='blue', 
    alpha=0.5
)

fig.patch(
    np.r_[dist, dist[::-1]]/1000,
    np.r_[z_coeff-z_error, (z_coeff+z_error)[::-1]], 
    color='blue', 
    fill_alpha=0.2, 
    line_alpha=0.2, 
    legend='std error interval of linear trend'
)

fig.legend.location = "bottom_left"
fig.xaxis.axis_label = 'Distance along coast [km]'
fig.yaxis.axis_label = 'Sea level rise per year [mm] (trend)'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="732c472a-6d92-4d03-835a-587c3b768a8d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("732c472a-6d92-4d03-835a-587c3b768a8d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("732c472a-6d92-4d03-835a-587c3b768a8d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '732c472a-6d92-4d03-835a-587c3b768a8d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"260f822b-a842-4901-b543-736f872fb666":{"roots":{"references":[{"attributes":{},"id":"14dbd78a-f46c-49de-b68d-496e125715ea","type":"ToolEvents"},{"attributes":{"label":{"value":"std error interval of linear trend"},"renderers":[{"id":"b314f2e7-df05-43a4-b68c-06bb7e75a2e2","type":"GlyphRenderer"}]},"id":"1d13c15b-138a-4127-80a5-8389248b44d8","type":"LegendItem"},{"attributes":{},"id":"7fe8b01a-dd47-45d9-b659-5599749b8e83","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Distance along coast [km]","formatter":{"id":"7fe8b01a-dd47-45d9-b659-5599749b8e83","type":"BasicTickFormatter"},"plot":{"id":"31e4e5cf-58fb-4524-ae3c-0657ac1993be","subtype":"Figure","type":"Plot"},"ticker":{"id":"83c241ec-5bc5-474d-a651-9b5b5dce30fb","type":"BasicTicker"}},"id":"294eb616-1378-43ef-93fb-8d28982ea5a5","type":"LinearAxis"},{"attributes":{"callback":null,"end":375.23475198999296},"id":"d23f4f3d-0e2f-4972-90de-b9b02627a5d9","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e3fa9f45-7420-4030-bc41-fa03a9c8047d","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"944a86ef-0c41-487a-8236-bbfeb13e9860","type":"Line"},{"attributes":{},"id":"83c241ec-5bc5-474d-a651-9b5b5dce30fb","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"blue"},"line_alpha":{"value":0.2},"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c91e3fae-3c48-4abc-8a88-c48412cf80a3","type":"Patch"},{"attributes":{"plot":{"id":"31e4e5cf-58fb-4524-ae3c-0657ac1993be","subtype":"Figure","type":"Plot"}},"id":"fa3e1b14-9660-4e21-b8df-e0b2150cd455","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"00061d4c-6bd8-44f3-862e-a1b8544cd4fb","type":"Title"},{"attributes":{"below":[{"id":"294eb616-1378-43ef-93fb-8d28982ea5a5","type":"LinearAxis"}],"left":[{"id":"25103def-0963-4bd7-8312-a79b70d8f5d0","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"294eb616-1378-43ef-93fb-8d28982ea5a5","type":"LinearAxis"},{"id":"d29b5574-f36b-4f82-9142-20578a24d114","type":"Grid"},{"id":"25103def-0963-4bd7-8312-a79b70d8f5d0","type":"LinearAxis"},{"id":"b016cbbd-c079-4ed4-9288-0082ceba1f13","type":"Grid"},{"id":"e3fa9f45-7420-4030-bc41-fa03a9c8047d","type":"BoxAnnotation"},{"id":"a9722267-696e-448c-8a20-bb2d6fc7d85b","type":"Legend"},{"id":"48d07aa1-0075-4660-a987-f9367cf701d0","type":"GlyphRenderer"},{"id":"b314f2e7-df05-43a4-b68c-06bb7e75a2e2","type":"GlyphRenderer"}],"title":{"id":"00061d4c-6bd8-44f3-862e-a1b8544cd4fb","type":"Title"},"tool_events":{"id":"14dbd78a-f46c-49de-b68d-496e125715ea","type":"ToolEvents"},"toolbar":{"id":"f3ef3c34-7393-4017-a810-79769a845dd0","type":"Toolbar"},"x_range":{"id":"d23f4f3d-0e2f-4972-90de-b9b02627a5d9","type":"Range1d"},"y_range":{"id":"0db86a40-cbf7-4c23-bfdf-1c1e726f8d2c","type":"Range1d"}},"id":"31e4e5cf-58fb-4524-ae3c-0657ac1993be","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"31e4e5cf-58fb-4524-ae3c-0657ac1993be","subtype":"Figure","type":"Plot"}},"id":"5b9e2a69-bf2a-4f31-8f36-5cb779f165fe","type":"SaveTool"},{"attributes":{"data_source":{"id":"7e433681-901c-44d6-aa2e-6602a78f3252","type":"ColumnDataSource"},"glyph":{"id":"8f0d297f-f004-4e7d-97e1-aaeaa84af081","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"944a86ef-0c41-487a-8236-bbfeb13e9860","type":"Line"},"selection_glyph":null},"id":"48d07aa1-0075-4660-a987-f9367cf701d0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"31e4e5cf-58fb-4524-ae3c-0657ac1993be","subtype":"Figure","type":"Plot"}},"id":"1c72b4ca-4a13-42c1-a950-71b0ee0dc7cd", ...

# %% [markdown]
# The first thing to be noted on this data is that the spread in this data is much larger. This is to be expected since the data is available since 1993, which is much shorter than the tidal data. The second thing to be noted is that the trend coefficient from the data is larger for the combination of satellite data and period, compared to the tidal data we showed before.
#
# To get a better view of the usability of satellite data for estimating the (regional) sea level rise speed along the Dutch coast, we compare equal periods for the sattelite data and the tidal data. We interpolate the locations of the tidal stations in the satellite data, to get the trend at the same location.

# %%
# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=rlr_data['name'].values.tolist())

# Determine the trends again for the rlr data
for name, station in rlr_data.iterrows():
    # Select the data from 1890 till now
    df = station['data'].loc[station['data'].year >= 1993]
    
    # Fit the linear model with wind
    fit, names = linear_model(df, with_wind=False, with_season=False)
    # Get the summary
    smry = fit.summary2(xname=names)
    # Determine the coefficient and standard error from the tables, and add to dataframe
    trend_coef = float(smry.tables[1].values[1, 0])
    trend_err = float(smry.tables[1].values[1, 1])
    station_data.loc[name, 'trend_coef'] = trend_coef
    station_data.loc[name, 'trend_stderr'] = trend_err
    trend_values.loc[station['name'], ('rlr', 'coeff')] = trend_coef
    trend_values.loc[station['name'], ('rlr', 'stderr')] = trend_err
    # Project the station on the coast line, to determine the projected distance
    station_data.loc[name, 'proj_distance'] = kustlijn.project(
        Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
    )

# Sort the station data by projected distance for plotting
station_data.sort_values(by='proj_distance', inplace=True)

# Determine the trends for the satellite data at the locations of the rlr stations
# Interpolate the for all (nine) RLR stations
for _, station in rlr_data.iterrows():
    trend_values.loc[station['name'], ('satellite', 'coeff')] = f_coeff(*station[['lon', 'lat']].values)[0] * 1000
    trend_values.loc[station['name'], ('satellite', 'stderr')] = f_error(*station[['lon', 'lat']].values)[0] * 1000

# %%
print(trend_values.astype(float).round(2).to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} & \multicolumn{2}{l}{rlr} & \multicolumn{2}{l}{satellite} \\
# {} & coeff & stderr &     coeff & stderr \\
# \midrule
# VLISSINGEN       &  3.50 &   0.67 &      3.67 &   0.88 \\
# HOEK VAN HOLLAND &  3.10 &   0.73 &      2.71 &   0.94 \\
# IJMUIDEN         &  2.82 &   0.84 &      2.62 &   0.92 \\
# DEN HELDER       &  2.53 &   0.91 &      3.08 &   0.93 \\
# HARLINGEN        &  4.51 &   1.09 &      3.57 &   0.89 \\
# DELFZIJL         &  3.95 &   1.05 &      3.07 &   0.90 \\
# \bottomrule
# \end{tabular}

# %%
names = ['RLR9', 'Satellite']
pandas.options.mode.chained_assignment = None

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(y_range=(0, 5.5), plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'orange']
source = {}

# Loop trough the different datasets to be plotted
dist = rlr_data['proj_distance'].values

source['RLR9'] = rlr_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance', 'name']]
source['RLR9']['proj_distance'] /= 1000
source['RLR9']['dataset'] = 'RLR9'
source['RLR9']['trend_coef'] = np.nan
source['RLR9']['trend_stderr'] = np.nan
source['RLR9'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['RLR9']['name'], 'rlr'].values

source['Satellite'] = rlr_data[['lat', 'lon', 'proj_distance', 'name']]
source['Satellite']['proj_distance'] /= 1000
source['Satellite']['dataset'] = 'Satellite'
source['Satellite']['trend_coef'] = np.nan
source['Satellite']['trend_stderr'] = np.nan
source['Satellite'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['Satellite']['name'], 'satellite'].values
    
for name, color in zip(names, colors):
    
    data = source[name]
    
    # Draw the sea level trend
    fig.line(dist/1000, data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = data['trend_coef'].values - data['trend_stderr'].values
    upper = data['trend_coef'].values + data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]]/1000, 
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2,
        line_alpha=0.0
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Linear trend coefficient (mm/year)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"BasicTickFormatter"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"ccf1b956-680a-4ccd-b742-3a9b22c4270a","type":"GlyphRenderer"}]},"id":"24bd613c-44da-48e4-a04f-e1012a0af8d7","type":"LegendItem"},{"attributes":{"data_source":{"id":"be2101dc-05ce-4bdc-8a6e-dc047128aee0","type":"ColumnDataSource"},"glyph":{"id":"9d6f30a3-2b57-4431-8c86-fea51e486a86","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a95e07d1-3f02-4c50-94de-ac0c5339be7c","type":"Circle"},"selection_glyph":null},"id":"3ff1cbf7-a2de-4967-8486-bead39e92f11","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDgPQpXkmlDQOKF54X0JlZAEhHPJEttVkBSjjxWbttiQEyXe/mPBWpAyEpSNvMucECuH98rdTZwQJNak0K+9XZAk1qTQr71dkCuH98rdTZwQMhKUjbzLnBATJd7+Y8FakBSjjxWbttiQBIRzyRLbVZA4oXnhfQmVkDgPQpXkmlDQKjRgQoLDy5A","dtype":"float64","shape":[18]},"y":{"__ndarray__":"YNLgSUd2BUBIjYVn0g8FQPEhtRqCWAFALp41Y4Kc+D/D790WnQr8P96c/y3TPfQ/TLVqbgezB0BHNCwwY04IQGKMnuE//wJAXUae+dmoEkBsRcbXfqkVQCY8ZF0VaBRAOaU/DvgICkC+rpZ1rKIMQIMxJcP/WwlAc0NC0NciDkDFjxmI7n8QQGAVXDuukBBA","dtype":"float64","shape":[18]}}},"id":"8b40ea1a-88a9-488a-89ad-7be8210e8d9e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"blue"},"line_alpha":{"value":0.0},"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7360ef25-aa95-4010-85c5- ...

# %% [markdown]
# The results from the satellite data match well with the results from the tidal stations. The 'zig-zag' differences are near mean filled NaN-values, so that could be a possible explaination for these differences. The standard errors have the some order of magnitude, however the standard error is somewhat larger in the Waddensea.
#
# The satellite data are a nice addition to the tidal station data, also because they span a large area, instead of a few point sources. This can help in identifying causes of regional sea level changes. A downside is the relatively short time series for which they are available. This results in a large spread, so the uncertainty around the 'actual' trend is large. This makes extrapolation to the near future (a useful application for practical purposes) tricky.

# %% [markdown]
# ## Conclusions
# In this notebook possible sources for obtaining more data for the sea level monitor where explored. These extra data can subsequently be used to get a better view on regional differences in the speed with which the sea level rises.
#
# First the extra tide gauges available from PSMSL where considered. Three extra stations, Maassluis, West-terschelling en Roompot Buiten, are available in the official rlr-dataset. The first two are located closely to other RLR-stations, while the last has only a short timeseries. Adding these stations to the sea level monitor thus provides not much added value.
#
# A second source of extra data is the metric dataset available on PSMSL. The data from this dataset are however from worse quality (which is also clearly communicated by PSMSL) than the rlr monthly data. This makes the dataset less useful for practical purposes.
#
# A last source of data is satellite data available though AVISO altimetry. These data coincide reasonably well with the tidal gauge data, and are available for the complete Northsea (and world), with an resolution of a quarter degree longitude and latitide. The data are however available from 1993 on, which gives a large uncertainty around the trend. This makes it difficult to use it for short term predictions. The availability across the whole North Sea makes it however a good source for finding or checking sources of sea level rise differences.
