# %% [markdown]
# # Extending the number of data sources from tidal gauge stations and satellite data
#
# This notebooks explores different sources for extending the number of data sources for the sea level monitor. These extra sources can be used for getting a grip on regional differences in the speed with which the sea level rises.
#
# The primary source of the tidal data is the PSMSL website. This website receives the tide gauge data from Rijkswaterstaat. The notebook get-data can be used to obtain the data.

# %%
# Standard Python packages
import io

# Python packages that need to be installed using pip or anaconda:
# For computations
import pandas
import numpy as np

# For GIS related function
import pyproj
from shapely.geometry import LineString, Point

# For loading netcdf
import netCDF4

# For plotting
import matplotlib.pyplot as plt
import bokeh.palettes
import bokeh.plotting
from bokeh.models import HoverTool

# Initialize modules for the jupyter notebook format
from nbformat import current
# %matplotlib inline
bokeh.io.output_notebook()

# Disable pandas warnings
pandas.options.mode.chained_assignment = None
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a54e0743-e3ff-4b02-9713-7031c80b2b07">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Define a function to read from functions from other notebooks

# %%
def execute_notebook(nbfile):
    """Function to run other notebook in this notebook"""
    with io.open(nbfile,encoding="utf8") as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)

# %% [markdown]
# A set of functions to get data is defined in the notebook 'get-data.py' We import this here.

# %%
execute_notebook('get-data.ipynb')
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Extended station collection
#
# Currently the methods of the sea level monitor are applief on data of six tidal stations along the Dutch coast. For these stations the data is available via PSMSL, and the data are converted to RLR with NAP correction. There is however more data available from PSMSL, partly in RLR, and partly metric data (NAP). In the next section of this notebook, this data is retireved and compared to the 'official' data in the sea level monitor.

# %%
rlr_data = get_station_data(dataset_name='rlr_monthly', coastline_code=150)
met_data = get_station_data(dataset_name='met_monthly', coastline_code=150)
# Out:
# found point 52.3799 3.75
# rlr_monthly 24 rlr
# rlr_monthly 236 rlr
# rlr_monthly 25 rlr
# rlr_monthly 23 rlr
# rlr_monthly 32 rlr
# rlr_monthly 22 rlr
# rlr_monthly 9 rlr
# rlr_monthly 1551 rlr
# rlr_monthly 20 rlr
# found point 52.3799 3.75
# met_monthly 24 met
# met_monthly 236 met
# met_monthly 25 met
# met_monthly 23 met
# met_monthly 32 met
# met_monthly 22 met
# met_monthly 9 met
# met_monthly 19 met
# met_monthly 1331 met
# met_monthly 1837 met
# met_monthly 36 met
# met_monthly 1507 met
# met_monthly 1551 met
# met_monthly 35 met
# met_monthly 20 met

# %% [markdown]
# Time series analysis of the gauge data, where the sea level y is described by a linear regression model with a trend, 18.6-year nodal cycle and the wind.

# %%
# Comments

colors = bokeh.palettes.Category20_15

stationsets = [
    [
        'VLISSINGEN',
        'HOEK VAN HOLLAND',
        'DEN HELDER',
        'DELFZIJL',
        'HARLINGEN',
        'IJMUIDEN'
    ],
    [
        'VLISSINGEN',
         'HOEK VAN HOLLAND',
         'DEN HELDER',
         'DELFZIJL',
         'HARLINGEN',
         'IJMUIDEN',
         'MAASSLUIS',
         'ROOMPOT BUITEN',
         'WEST-TERSCHELLING'
    ],
    met_data['name'].squeeze().tolist()
]

for stationset in stationsets:
    fig = bokeh.plotting.figure(
        x_range=(1840, 2020),
        plot_width=950,
        plot_height=450
    )
    
    for color, name in zip(colors, stationset):
        # Check if station is available in rlr set, otherwise use metric set
        if name in rlr_data['name'].values:
            station = rlr_data.set_index('name').loc[name]
            linestyle = 'solid'
        else:
            station = met_data.set_index('name').loc[name]
            linestyle = 'dashed'
        
        # Some series contain -9999, we set these values to nan
        station['data'].loc[(station['data']['height'] < -9000), 'height'] = np.nan
        
        # Select the data after 1890
        df = station['data'].loc[station['data'].year >= 1890]
        
        fit, names = linear_model(df, with_wind=False, with_season=False)
        
        fig.line(
            fit.model.exog[:, 1] + 1970,
            fit.predict() / 1e3,
            line_width=3,
            alpha=0.8,
            legend=station.name,
            color=color,
            line_dash=linestyle
        )

    fig.legend.location = "top_left"
    fig.yaxis.axis_label = 'Sea water level (m+NAP)'
    fig.xaxis.axis_label = 'Year'
    
    bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9539a23d-a02d-4095-9b04-b5ac059d3074"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9539a23d-a02d-4095-9b04-b5ac059d3074");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9539a23d-a02d-4095-9b04-b5ac059d3074");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9539a23d-a02d-4095-9b04-b5ac059d3074' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"19a24499-53e6-4b30-a10d-01403b564bca":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#aec7e8"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d881f99f-efd7-4d8c-ab2e-48cf7408c287","type":"Line"},{"attributes":{"plot":{"id":"8d439d91-569d-4fa5-94c4-55f630d65903","subtype":"Figure","type":"Plot"}},"id":"080e726e-b4b4-41ce-957e-601e0c6b6ac7","type":"SaveTool"},{"attributes":{"label":{"value":"HOEK VAN HOLLAND"},"renderers":[{"id":"800c98d9-abcd-48b5-b98c-7ec919c2c34f","type":"GlyphRenderer"}]},"id":"c4754988-5eca-4892-9c0b-988ed33216eb","type":"LegendItem"},{"attributes":{"axis_label":"Sea water level (m+NAP)","formatter":{"id":"380d2b0c-ebcf-4310-9579-be842e357e5a","type":"BasicTickFormatter"},"plot":{"id":"8d439d91-569d-4fa5-94c4-55f630d65903","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe453e35-e496-4a23-b2e3-a7030f3f98c6","type":"BasicTicker"}},"id":"05c5c72b-b7f1-4901-b700-3e449cda1eec","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1524]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1524]}}},"id":"e34b75cf-f4dd-45b0-af4b-0548074214c7","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"8d439d91-569d-4fa5-94c4-55f630d65903","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe453e35-e496-4a23-b2e3-a7030f3f98c6","type":"BasicTicker"}},"id":"6b82753e-6516-49e5-b8ad-2d6dfe31004f","type":"Grid"},{"attributes":{"data_source":{"id":"cd5b7651-429f-47c8-8edb-32623e6dbb80","type":"ColumnDataSource"},"glyph":{"id":"30a3fc67-418d-41f5-9e80-76788ba0a8ca","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"57eec32e-a588-46a8-891c-a2364562a32e","type":"Line"},"selection_glyph":null},"id":"06c3efe3-c758-4002-bd31-7016b1126614","type":"GlyphRenderer"},{"attributes":{"label":{"value":"VLISSINGEN"},"renderers":[{"id":"06c3efe3-c758-4002-bd31-7016b1126614","type":"GlyphRenderer"}]},"id":"363b9ab7-28b7-4053-aef0-0ee735534c30","type":"LegendItem"},{"attributes":{"data_source":{"id":"d1a26140-4614-48e2-8471-97fcb3f49b11","type":"ColumnDataSource"},"glyph":{"id":"d881f99f-efd7-4d8c-ab2e-48cf7408c287","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"
type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"05d9886a-bb45-4fd8-9cbc-94f2ddebba09","type":"Line"},"selection_glyph":null},"id":"96c8e1a2-efe1-4e4c-a0b2-18b890f66c09","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d4004e87-34c6-4372-a27e-78e218a69751","type":"ColumnDataSource"},"glyph":{"id":"7971a9d4-0b57-4353-b4f8-96c41fa5c100","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"81b3bb24-9e9e-4e99-b724-9218f088f795","type":"Line"},"selection_glyph":null},"id":"eda8db3a-1761-4d07-bdde-8f143133fe54","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a458decd-8367-4206-adca-84cdc25fd48e","type":"Line"},{"attributes":{"data_source":{"id":"163e9508-e855-4426-b88b-537e53ac5e68","type":"ColumnDataSource"},"glyph":{"id":"ec55eb5a-c3df-4186-bf94-7247384e56cc","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ab525ef6-b67a-43cb-8e5f-c3922a5382f6","type":"Line"},"selection_glyph":null},"id":"530b81cb-0486-4cea-b20f-4682daf6aca5","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"81b3bb24-9e9e-4e99-b724-9218f088f795","type":"Line"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#c49c94"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7971a9d4-0b57-4353-b4f8-96c41fa5c100","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[948]},"y":{"__ndarray__":"...","dtype":"float64","shape":[948]}}},"id":"e03c5366-5858-440e-b32a-4f69e3716d4d","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"34030fef-d7c9-406e-9c3c-94779159935b","type":"Line"},{"attributes":{"data_source":{"id":"2020fb78-8dc4-4c90-9ecc-ae0341c02e75","type":"ColumnDataSource"},"glyph":{"id":"5c0308a3-2a03-4f48-9a38-e48c2dddfcf9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dc95cbde-6f4a-4687-9a88-3b24ffce0cfc","type":"Line"},"selection_glyph":null},"id":"8b912824-e712-4df3-a849-54d8b98cdae3","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":3},"x":{"field":"x"},"y ...

# %% [markdown]
# The top figure contains the fitted sea level trends for the 6 stations that are currently used in the sea level monitor. All series are part of the RLR monthly dataset from PSMSL.
#
# The second figure adds 3 other stations that are also present in the RLR monlthy set from PSMSL. Note that Roomput-Buiten is a very short series, since the station is installed after constructing the Eastern Scheldt storm surge barrier. The standard error around this trend is therefor larger than around the other stations, which is discussed later.
#
# The last figure contains another 6 extra stations, that are in the metric monthly dataset (the dashes lines). The quality of this data is worse, such that PSMSL advices: "in general we highly recommend that you do not use these records". For this exploratory study we do use the data, but keep the advice in mind. The trends from these stations are visually less consistent than the first 6 or 9 trends. Partly due to the shorter series (Frederikse et al. (2016) says at least a 60 year record is needed to detect a 2 mm/year trend), but likely also due to to the worse data quality of the metric monthly data set.

# %% [markdown]
# ## Differences along the Dutch coast
#
# In the next step, the linear model will be used to determine regional differences along the Dutch coast. To do so, every station along the dutch coast is projects on a line along the coast. The coefficient of the linear trend component, as well as the standard error in this coefficient are used to show the speed of the sea level rise along the coast.

# %%
crds = [
    (12000, 377000),
    (12000, 378000),
    (20407, 397159),
    (87784, 468350),
    (111514, 554797),
    (189909, 600139),
    (263643, 607342),
    (264643, 607342)
]
    
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

kustlijn = LineString(crds)

# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'met', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=met_data['name'].values.tolist())

for station_data, tag in zip([rlr_data, met_data], ['rlr', 'met']):
    for name, station in station_data.iterrows():
        # Select the data from 1890 till now
        df = station['data'].loc[station['data'].year >= 1890]
        # Fit the linear model with wind
        fit, names = linear_model(df, with_wind=False, with_season=False)
        # Get the summary
        smry = fit.summary2(xname=names)
        # Determine the coefficient and standard error from the tables, and add to dataframe
        trend_values.loc[station['name'], (tag, 'coeff')] = float(smry.tables[1].values[1, 0])
        trend_values.loc[station['name'], (tag, 'stderr')] = float(smry.tables[1].values[1, 1])
        station_data.loc[name, 'trend_coef'] = float(smry.tables[1].values[1, 0])
        station_data.loc[name, 'trend_stderr'] = float(smry.tables[1].values[1, 1])

        # Project the station on the coast line, to determine the projected distance
        station_data.loc[name, 'proj_distance'] = kustlijn.project(
            Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
        )

    # Sort the station data by projected distance for plotting
    station_data.sort_values(by='proj_distance', inplace=True)

# %%
names = ['RLR6', 'RLR9', 'Metric']

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'green', 'orange']
source = {}

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    station_data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    station_data = station_data.set_index('name').loc[stationset]
    station_data.sort_values(by='proj_distance', inplace=True)
    
    dist = station_data['proj_distance'].values
    
    source[name] = station_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance']]
    source[name]['proj_distance'] /= 1000
    source[name]['dataset'] = name
    
    # Add

    # Draw the sea level trend
    fig.line(dist / 1000, station_data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = station_data['trend_coef'].values - station_data['trend_stderr'].values
    upper = station_data['trend_coef'].values + station_data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]] / 1000,
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2, 
        line_alpha=0.0
    )


fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42c5d8ad-401f-4995-89e5-c3eb2c9b3f07"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("42c5d8ad-401f-4995-89e5-c3eb2c9b3f07");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42c5d8ad-401f-4995-89e5-c3eb2c9b3f07");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42c5d8ad-401f-4995-89e5-c3eb2c9b3f07' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ec8f34d9-e141-4e9c-9d8d-2bee4cea733f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":
colors = ['blue', 'green', 'orange']

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    data = data.set_index('name').loc[stationset]
    
    # compute the mean for metric data
    grouped = pandas.concat(data['data'].tolist())[['year', 't', 'height', 'u', 'v', 'u2', 'v2']].groupby(['year', 't'])
    mean = grouped.mean().reset_index()
    # filter out non-trusted part (before NAP)
    mean = mean[mean['year'] >= 1890].copy()
    linear_fit, names = linear_model(mean, with_wind=False, with_season=False)

    # Draw the sea level trend
    fig.line(
        linear_fit.model.exog[:, 1] + 1970, 
        linear_fit.predict() / 1000.,
        line_width=3, 
        legend=name, 
        color=color,
        alpha=0.5
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'year'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b206d884-2257-4978-a961-748e2bda7447"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b206d884-2257-4978-a961-748e2bda7447");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b206d884-2257-4978-a961-748e2bda7447");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b206d884-2257-4978-a961-748e2bda7447' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cad92eff-4c6e-4c96-b48f-5571ac79f084":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1524]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1524]}}},"id":"be555318-5f70-41eb-a25d-bf0797df2ebe","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"22948a38-64b8-45c8-bee6-5490c9b91048","type":"Title"},{"attributes":{"items":[{"id":"6b989fb2-705f-406e-9c93-049c118b882a","type":"LegendItem"},{"id":"3032e2d7-2ffc-4d70-a48a-a7ad5a2f8229","type":"LegendItem"},{"id":"7b856c70-2f33-4ab2-b6e5-daaa4338feb5","type":"LegendItem"}],"location":"top_left","plot":{"id":"cbb771af-c69c-42e7-a752-fa3cb43498b1","subtype":"Figure","type":"Plot"}},"id":"36bf100c-acfd-4ecb-bcc7-67b426b79218","type":"Legend"},{"attributes":{},"id":"8e6d9e29-a7f0-445e-9db8-a73a499c0696","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1524]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1524]}}},"id":"ea0086e7-3a26-4a65-a005-4614e6fc1f51","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"cbb771af-c69c-42e7-a752-fa3cb43498b1","subtype":"Figure","type":"Plot"}},"id":"478cf955-b42f-4c70-932b-feb7a574d3b2","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a31ef908-5b02-4c81-9133-32e64398420b","type":"PanTool"},{"id":"478cf955-b42f-4c70-932b-feb7a574d3b2","type":"WheelZoomTool"},{"id":"32396061-7893-4f4a-bb5d-60cf96f8fc57","type":"BoxZoomTool"},{"id":"87905a47-898f-4184-88e7-52b5ace371ff","type":"SaveTool"},{"id":"1020af8a-e124-4927-b978-09fab71d6322","type":"ResetTool"},{"id":"6815be97-b184-4c26-b792-1aa5c2c50fcb","type":"HelpTool"}]},"id":"700b2c2a-ef36-4491-a0cc-ec1a8e7ee546","type":"Toolbar"},{"attributes":{},"id":"517d2527-dd15-4ffc-82a6-e6ee8a19866e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"cbb771af-c69c-42e7-a752-fa3cb43498b1","subtype":"Figure","type":"Plot"}},"id":"87905a47-898f-4184-88e7-52b5ace371ff","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7317b266-5ac3-4f41-be6e-89be243d7182","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"45ac3fa2-7596-4ae3-8b5a-653ea2c2ff56","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"d0a35056-c867-4918-9273-d1492f79bbf9","type":"ColumnDataSource"},"glyph":{"id":"248b93f8-a7f6-45fb-a53c-a8830856d7ce","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"93cd2bcb-8f95-48dd-95b6-6d3467d91213","type":"Line"},"selection_glyph":null},"id":"4e5234e3-e0af-44b3-b7a3-5f5d6542567c","type":"GlyphRenderer"},{"attributes":{},"id":"f1194258-a639-4513-8903-d588c2c5b171","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"be555318-5f70-41eb-a25d-bf0797df2ebe","type":"ColumnDataSource"},"glyph":{"id":"7317b266-5ac3-4f41-be6e-89be243d7182","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e4d4c937-fb21-4d82-9b39-1ed46e152dec","type":"Line"},"selection_glyph":null},"id":"0eac4367-bceb-476b-a478-fda1e8098e2a","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"cbb771af-c69c-42e7-a752-fa3cb43498b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"fed5091f-87fd-4670-986d-59460a2261b8","type":"BasicTicker"}},"id":"4137c6df-2ac5-4475-a4d5-c9207f00fc6d","type":"Grid"},{"attributes":{"below":[{"id":"468b558b-0aad-461d-96c2-dfc58f65b3f1","type":"LinearAxis"}],"left":[{"id":"ebdcb54f-bad7-4ede-949c-eb4cc457afe5","type":"LinearAxis"}],"plot_hei ...

# %% [markdown]
# First we compare the effects of adding the three extra stations for which the RLR data can be retrieved at PSMSL. The trends show a that adding the three stations gives higher values around 1900 and equal values around 2000. These differences can be explained by viewing the trends of the 3 extra stations. The addition of West-Terschelling and Roompot-Buiten gives lower values in the more recent part of the trend, while adding Maassluis raises the trend over the full range.
#
# We also compare the rlr data to the metric stations. The trend does not differ considerably from the RLR trends. However, as we saw before, many of the metric stations have a shorter time range for which the data are available. Also some of the 'metric stations' are located at a location not directly at the coast, but for example inside the Eastern Scheldt. The quality if these data is thus worse than the data of the rlr stations.
#
# The trends shown in the following table show that the uncertainty around the metric data is larger, while there is no clear added value in using the extra dataset.

# %%
trend_values.dropna(how='all', axis=1)
# Out:
#                          rlr                 met
#                        coeff     stderr    coeff     stderr
# DELFZIJL             1.96483  0.0906629  1.93285  0.0906437
# WEST-TERSCHELLING     1.1558   0.134337  1.01774   0.133946
# HARLINGEN            1.33325  0.0930253  1.30527  0.0929743
# DEN HELDER           1.51113  0.0802395  1.44318  0.0802333
# IJMUIDEN              2.1365   0.076006  2.05256  0.0761078
# HOEK VAN HOLLAND     2.37837  0.0678681  2.26645   0.067959
# MAASSLUIS            1.74248  0.0700071  1.64655  0.0700645
# HELLEVOETSLUIS           NaN        NaN  1.79136   0.139246
# STELLENDAM BUITEN        NaN        NaN  3.91898    1.00524
# HARINGVLIET              NaN        NaN  2.51307   0.762284
# BROUWERSHAVEN            NaN        NaN   1.9461   0.128966
# BROUWERSHAVENSE GAT      NaN        NaN  1.65435   0.470682
# ROOMPOT BUITEN       2.73719   0.536844  1.26855   0.462415
# ZIERIKZEE                NaN        NaN   1.9804  0.0987289
# VLISSINGEN           2.17441  0.0607146   2.0545  0.0607678

# %% [markdown]
# ## Satellite data
#
# Next to the data from the tidal stations, there is also sea level data available from satellite observations. In this section of the notebook, we explore these data and compare them to the data from the tidal stations.

# %% [markdown]
# Now we load the satellite data from the netCDF4 file. First de latitude en longitude (axes) of the data are loaded, after which we use the data around the Dutch coast.

# %%
# Import sea level data (USER DEFINED LOCATION)
ds = netCDF4.Dataset(r'dt_global_merged_msla_h_merged.nc')

# Get longitude and latitude
lon = ds.variables['lon'][:]
lat = ds.variables['lat'][:]

# Determine relevant part
lon_selection = lon[(lon > 2) * (lon < 7)]
lat_selection = lat[(lat > 51) * (lat < 54.5)]

# Download sea level averages for relevant part
sla = ds.variables['sla'][:, np.in1d(lat, lat_selection), np.in1d(lon, lon_selection)]

# Get the time stamps of the 
time = netCDF4.num2date(ds.variables['time'][:], ds.variables['time'].units)

# %% [markdown]
# We apply the linear model of the sea level data on the data:

# %%
# Load coorindate systems for transformation
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

# Empty list for appending satellite data per coordinate
satellite_data = []

# Loop trough points in relevant range
years = [time[i].year + time[i].month / 12. for i in range(len(time))]
coeff = np.zeros((len(lat_selection), len(lon_selection)))
error = np.zeros_like(coeff)

for i, x in enumerate(lon_selection):
    for j, y in enumerate(lat_selection):
        # Add data
        data = pandas.DataFrame(columns=['year', 'height'])
        data['year'] = years
        data['height'] = sla[:, j, i]
        
        # Skip the coordinate if it is masked
        if any(sla[:, j, i].mask):
            coeff[j, i] = np.nan
            error[j, i] = np.nan
            continue            
        
        # Fit model
        fit, names = linear_model(data, with_wind=False, with_season=False)
        smry = fit.summary2(xname=names)
        
        # Add to list
        trend_coef = float(smry.tables[1].values[1, 0])
        trend_stderr = float(smry.tables[1].values[1, 1])
        satellite_data.append([x, y, trend_coef, trend_stderr, data])
        
        # Add to 2d-arrays
        coeff[j, i] = trend_coef
        error[j, i] = trend_stderr
        
satellite_data = pandas.DataFrame(
    satellite_data,
    columns=['lon', 'lat', 'trend_coef', 'trend_stderr', 'data']
)

# %%
xy = np.loadtxt(r'landboundary.txt')
fig, ax = plt.subplots(figsize=(15, 10))

xy = pyproj.transform(RD, WGS84, *xy.T)

ax.plot(*xy, color='0.9')
ax.plot(*met_data[['lon', 'lat']].values.T, marker='.', color='C3', ls='')

lon_step = lon_selection[1] - lon_selection[0]
lat_step = lat_selection[1] - lat_selection[0]

ws = (min(lon_selection) - 0.5 * lon_step, min(lat_selection) - 0.5 * lat_step)
en = (max(lon_selection) + 0.5 * lon_step, max(lat_selection) + 0.5 * lat_step)
im = ax.imshow(
    coeff*1000,
    extent=(ws[0], en[0], ws[1], en[1]),
    origin='lower',
    aspect=1.5
)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

cb = plt.colorbar(im)
cb.set_label('Sea level rise [mm/year]')

# %% [markdown]
# We compare this data to the tidal gauge data. To do so, we interpolate the coastline on which we projected the gauges earlier on in the satellite data. Note that for this interpolation the NaN values are filled with the mean of the values in the researched area. This can affect the result for locations close to the white parts in the figure above.

# %%
from scipy.interpolate import interp2d

# Fill copies of the 2d-arrays with average values at the position of the NaN's
coeff_notnull = coeff.copy()
coeff_notnull[np.isnan(coeff_notnull)] = np.nanmean(coeff)
error_notnull = error.copy()
error_notnull[np.isnan(error_notnull)] = np.nanmean(error)

# Define interpolation function
f_coeff = interp2d(lon_selection, lat_selection, coeff_notnull, kind='linear')
f_error = interp2d(lon_selection, lat_selection, error_notnull, kind='linear')

# Define a grid for plotting
dist = np.linspace(0, kustlijn.length, 200)

# Interpolate coordinaties along the coastline
xy = np.vstack([pyproj.transform(RD, WGS84, *kustlijn.interpolate(i).coords[0]) for i in dist])
z_coeff = np.array([f_coeff(x, y)[0] for x, y in xy]) * 1000
z_error = np.array([f_error(x, y)[0] for x, y in xy]) * 1000

# Draw the sea level trend
fig = bokeh.plotting.figure(
    x_range=(0, max(dist)/1000),
    y_range=(0, 5.0),
    plot_width=900,
    plot_height=400
)

fig.line(
    dist/1000,
    z_coeff, 
    line_width=3,
    legend='coefficient of linear trend', 
    color='blue', 
    alpha=0.5
)

fig.patch(
    np.r_[dist, dist[::-1]]/1000,
    np.r_[z_coeff-z_error, (z_coeff+z_error)[::-1]], 
    color='blue', 
    fill_alpha=0.2, 
    line_alpha=0.2, 
    legend='std error interval of linear trend'
)

fig.legend.location = "bottom_left"
fig.xaxis.axis_label = 'Distance along coast [km]'
fig.yaxis.axis_label = 'Sea level rise per year [mm] (trend)'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dbef63ff-5a1c-49b4-9c2f-f7f0358dcbab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dbef63ff-5a1c-49b4-9c2f-f7f0358dcbab");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dbef63ff-5a1c-49b4-9c2f-f7f0358dcbab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dbef63ff-5a1c-49b4-9c2f-f7f0358dcbab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"04133d5e-23f5-4d09-b7cb-4e45bda455af":{"roots":{"references":[{"attributes":{"plot":{"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"},"ticker":{"id":"a1965aa5-6537-487f-bc48-d57ba9a7747c","type":"BasicTicker"}},"id":"c9437d04-2c91-44bc-9be0-6f495c9f0a81","type":"Grid"},{"attributes":{"label":{"value":"std error interval of linear trend"},"renderers":[{"id":"c1aa333e-10dc-416b-8e06-8f30d56bcb07","type":"GlyphRenderer"}]},"id":"9bcc59e7-56ae-453d-a019-09bab4fa26bb","type":"LegendItem"},{"attributes":{"plot":null,"text":""},"id":"e7c128d6-92ef-4c38-9579-4ed2d2e447ca","type":"Title"},{"attributes":{"callback":null,"end":375.23475198999296},"id":"daf8940e-63c8-4914-9f29-28de6cc39b1c","type":"Range1d"},{"attributes":{},"id":"a1965aa5-6537-487f-bc48-d57ba9a7747c","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"455f3c2e-3e3f-4eb7-b551-9845b7959ad2","type":"Line"},{"attributes":{"below":[{"id":"b239bb1c-174b-49b6-8b9e-e877da001bb6","type":"LinearAxis"}],"left":[{"id":"2e016b68-a265-495f-966f-48de9d6a0fd4","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"b239bb1c-174b-49b6-8b9e-e877da001bb6","type":"LinearAxis"},{"id":"c9437d04-2c91-44bc-9be0-6f495c9f0a81","type":"Grid"},{"id":"2e016b68-a265-495f-966f-48de9d6a0fd4","type":"LinearAxis"},{"id":"767feb08-2285-4a00-ad77-51ccf52f3445","type":"Grid"},{"id":"33838c41-2e40-4616-9ef3-7d75587df7ec","type":"BoxAnnotation"},{"id":"d3b1e67a-1338-4488-89be-7603fd341edf","type":"Legend"},{"id":"345a529d-b9d4-4c61-939b-1c2691cdf00c","type":"GlyphRenderer"},{"id":"c1aa333e-10dc-416b-8e06-8f30d56bcb07","type":"GlyphRenderer"}],"title":{"id":"e7c128d6-92ef-4c38-9579-4ed2d2e447ca","type":"Title"},"tool_events":{"id":"845bc3ed-9124-4f5e-b3b8-8e5f453dab98","type":"ToolEvents"},"toolbar":{"id":"0f5b9c05-0ccb-4b98-b86c-789c3cdf1412","type":"Toolbar"},"x_range":{"id":"daf8940e-63c8-4914-9f29-28de6cc39b1c","type":"Range1d"},"y_range":{"id":"b986c738-ea8b-456a-a548-e3bb99b5d327","type":"Range1d"}},"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":5.0},"id":"b986c738-ea8b-456a-a548-e3bb99b5d327","type":"Range1d"},{"attributes":{"plot":{"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"}},"id":"5941f8c6-e6db-4bb0-b2df-31c73c83116b","type":"HelpTool"},{"attributes":{"axis_label":"Sea level rise per year [mm] (trend)","formatter":{"id":"cdad5b6e-6e27-4b48-b147-18bf4699e482","type":"BasicTickFormatter"},"plot":{"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"},"ticker":{"id":"99d67bd3-8be3-431e-acce-694c26f54847","type":"BasicTicker"}},"id":"2e016b68-a265-495f-966f-48de9d6a0fd4","type":"LinearAxis"},{"attributes":{"axis_label":"Distance along coast [km]","formatter":{"id":"f05f3db0-350c-45f9-82cb-2d3fac765133","type":"BasicTickFormatter"},"plot":{"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"},"ticker":{"id":"a1965aa5-6537-487f-bc48-d57ba9a7747c","type":"BasicTicker"}},"id":"b239bb1c-174b-49b6-8b9e-e877da001bb6","type":"LinearAxis"},{"attributes":{},"id":"cdad5b6e-6e27-4b48-b147-18bf4699e482","type":"BasicTickFormatter"},{"attributes":{},"id":"845bc3ed-9124-4f5e-b3b8-8e5f453dab98","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[400]},"y":{"__ndarray__":"...","dtype":"float64","shape":[400]}}},"id":"91169c51-1558-4cdf-b73e-064410dce6dd","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"68a3c75c-54c1-4ef0-b0ca-820b27b8e991","subtype":"Figure","type":"Plot"},"ticker":{"id":"99d67bd3-8be3-431e-acce-694c26f54847","type":"BasicTicker"}},"id":"767feb08-2285-4a00-ad77-51ccf52f3445","type":"Grid"},{"attributes":{},"id":"f05f3db0-350c-45f9-82cb-2d3fac765133","type":"BasicTic ...

# %% [markdown]
# The first thing to be noted on this data is that the spread in this data is much larger. This is to be expected since the data is available since 1993, which is much shorter than the tidal data. The second thing to be noted is that the trend coefficient from the data is larger for the combination of satellite data and period, compared to the tidal data we showed before.
#
# To get a better view of the usability of satellite data for estimating the (regional) sea level rise speed along the Dutch coast, we compare equal periods for the sattelite data and the tidal data. We interpolate the locations of the tidal stations in the satellite data, to get the trend at the same location.

# %%
# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=rlr_data['name'].values.tolist())

# Determine the trends again for the rlr data
for name, station in rlr_data.iterrows():
    # Select the data from 1890 till now
    df = station['data'].loc[station['data'].year >= 1993]
    
    # Fit the linear model with wind
    fit, names = linear_model(df, with_wind=False, with_season=False)
    # Get the summary
    smry = fit.summary2(xname=names)
    # Determine the coefficient and standard error from the tables, and add to dataframe
    trend_coef = float(smry.tables[1].values[1, 0])
    trend_err = float(smry.tables[1].values[1, 1])
    station_data.loc[name, 'trend_coef'] = trend_coef
    station_data.loc[name, 'trend_stderr'] = trend_err
    trend_values.loc[station['name'], ('rlr', 'coeff')] = trend_coef
    trend_values.loc[station['name'], ('rlr', 'stderr')] = trend_err
    # Project the station on the coast line, to determine the projected distance
    station_data.loc[name, 'proj_distance'] = kustlijn.project(
        Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
    )

# Sort the station data by projected distance for plotting
station_data.sort_values(by='proj_distance', inplace=True)

# Determine the trends for the satellite data at the locations of the rlr stations
# Interpolate the for all (nine) RLR stations
for _, station in rlr_data.iterrows():
    trend_values.loc[station['name'], ('satellite', 'coeff')] = f_coeff(*station[['lon', 'lat']].values)[0] * 1000
    trend_values.loc[station['name'], ('satellite', 'stderr')] = f_error(*station[['lon', 'lat']].values)[0] * 1000

# %%
trend_values
# Out:
#                        rlr           satellite
#                      coeff    stderr     coeff    stderr
# VLISSINGEN         3.41202  0.729268   3.66833  0.875533
# ROOMPOT BUITEN     3.37883  0.746104   3.68774  0.918776
# HOEK VAN HOLLAND   2.96762  0.799398    2.7089  0.942983
# MAASSLUIS          2.35407  0.815856   2.90831  0.906199
# IJMUIDEN           2.66601   0.91342   2.61885  0.924794
# DEN HELDER         2.25974  0.994643   3.07708  0.931964
# WEST-TERSCHELLING  4.03203   1.06961   3.86213  0.936762
# HARLINGEN           4.2269   1.18862   3.56716  0.887904
# DELFZIJL           3.51976   1.14513   3.06756  0.902371

# %%
names = ['RLR9', 'Satellite']
pandas.options.mode.chained_assignment = None

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(y_range=(0, 5.5), plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'orange']
source = {}

# Loop trough the different datasets to be plotted
dist = rlr_data['proj_distance'].values

source['RLR9'] = rlr_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance', 'name']]
source['RLR9']['proj_distance'] /= 1000
source['RLR9']['dataset'] = 'RLR9'
source['RLR9']['trend_coef'] = np.nan
source['RLR9']['trend_stderr'] = np.nan
source['RLR9'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['RLR9']['name'], 'rlr'].values

source['Satellite'] = rlr_data[['lat', 'lon', 'proj_distance', 'name']]
source['Satellite']['proj_distance'] /= 1000
source['Satellite']['dataset'] = 'Satellite'
source['Satellite']['trend_coef'] = np.nan
source['Satellite']['trend_stderr'] = np.nan
source['Satellite'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['Satellite']['name'], 'satellite'].values
    
for name, color in zip(names, colors):
    
    data = source[name]
    
    # Draw the sea level trend
    fig.line(dist/1000, data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = data['trend_coef'].values - data['trend_stderr'].values
    upper = data['trend_coef'].values + data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]]/1000, 
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2,
        line_alpha=0.0
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Linear trend coefficient (mm/year)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f93be902-c4b9-4812-9b61-9b8b572695a5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f93be902-c4b9-4812-9b61-9b8b572695a5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f93be902-c4b9-4812-9b61-9b8b572695a5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f93be902-c4b9-4812-9b61-9b8b572695a5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"755239d2-0f48-47c8-a114-ad83fac5d9a9":{"roots":{"references":[{"attributes":{"below":[{"id":"9c944e38-be05-4a58-afc6-53917dd582b6","type":"LinearAxis"}],"left":[{"id":"d993bffd-4772-43bc-9509-a87b2e7318a5","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"9c944e38-be05-4a58-afc6-53917dd582b6","type":"LinearAxis"},{"id":"c4ab5c72-43c4-410a-868b-be0240d9629f","type":"Grid"},{"id":"d993bffd-4772-43bc-9509-a87b2e7318a5","type":"LinearAxis"},{"id":"861c8816-be1e-4779-a664-c6d4bc73c2d2","type":"Grid"},{"id":"5fab0603-4276-4dac-9c81-4eac5379aeca","type":"BoxAnnotation"},{"id":"248804a6-946d-435e-b053-235c0c89db5e","type":"Legend"},{"id":"ccf1b956-680a-4ccd-b742-3a9b22c4270a","type":"GlyphRenderer"},{"id":"3ff1cbf7-a2de-4967-8486-bead39e92f11","type":"GlyphRenderer"},{"id":"0b859e42-cbe9-421a-b0d1-e8aad14f6edd","type":"GlyphRenderer"},{"id":"6a77853e-59ef-4d1f-9c73-1b5e0a2ab0ba","type":"GlyphRenderer"},{"id":"ea4da2e5-770b-496d-a5ab-b898edf3e757","type":"GlyphRenderer"},{"id":"582fa123-6fae-49dc-a298-c598e5dd6f4e","type":"GlyphRenderer"}],"title":{"id":"9812ea3a-a465-4095-b6a4-55d0d21e8803","type":"Title"},"tool_events":{"id":"ef159637-94f3-4050-8d2b-3dc537b95600","type":"ToolEvents"},"toolbar":{"id":"1c86baba-7e8e-4fd1-bba7-e51c9d76351e","type":"Toolbar"},"x_range":{"id":"d1ce2076-7503-41c6-bad9-8b7808a78dd3","type":"DataRange1d"},"y_range":{"id":"0b770bce-6b6e-4991-a01c-f6466a83daed","type":"Range1d"}},"id":"2ea8afbc-202b-480d-8ba8-b288cebc2e3e","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"9b03d6cd-da7b-4a5b-9ac6-f1c649b5fd57","type":"ColumnDataSource"},"glyph":{"id":"71093da8-498f-4403-b529-bb4f74efcae7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1e900ab5-f925-4124-bd56-de5a086691c6","type":"Line"},"selection_glyph":null},"id":"ccf1b956-680a-4ccd-b742-3a9b22c4270a","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e900ab5-f925-4124-bd56-de5a086691c6","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"9812ea3a-a465-4095-b6a4-55d0d21e8803","type":"Title"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"71093da8-498f-4403-b529-bb4f74efcae7","type":"Line"},{"attributes":{},"id":"cd699920-28d9-4a23-8096-9b773ae6c6b4","type":"BasicTickFormatter"},{"attributes":{},"id":"7b82a7ee-3614-483c-9d2f-743c72704369","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"ccf1b956-680a-4ccd-b742-3a9b22c4270a","type":"GlyphRenderer"}]},"id":"24bd613c-44da-48e4-a04f-e1012a0af8d7","type":"LegendItem"},{"attributes":{"data_source":{"id":"be2101dc-05ce-4bdc-8a6e-dc047128aee0","type":"ColumnDataSource"},"glyph":{"id":"9d6f30a3-2b57-4431-8c86-fea51e486a86","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a95e07d1-3f02-4c50-94de-ac0c5339be7c","type":"Circle"},"selection_glyph":null},"id":"3ff1cbf7-a2de-4967-8486-bead39e92f11","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDgPQpXkmlDQOKF54X0JlZAEhHPJEttVkBSjjxWbttiQEyXe/mPBWpAyEpSNvMucECuH98rdTZwQJNak0K+9XZAk1qTQr71dkCuH98rdTZwQMhKUjbzLnBATJd7+Y8FakBSjjxWbttiQBIRzyRLbVZA4oXnhfQmVkDgPQpXkmlDQKjRgQoLDy5A","dtype":"float64","shape":[18]},"y":{"__ndarray__":"YNLgSUd2BUBIjYVn0g8FQPEhtRqCWAFALp41Y4Kc+D/D790WnQr8P96c/y3TPfQ/TLVqbgezB0BHNCwwY04IQGKMnuE//wJAXUae+dmoEkBsRcbXfqkVQCY8ZF0VaBRAOaU/DvgICkC+rpZ1rKIMQIMxJcP/WwlAc0NC0NciDkDFjxmI7n8QQGAVXDuukBBA","dtype":"float64","shape":[18]}}},"id":"8b40ea1a-88a9-488a-89ad-7be8210e8d9e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"blue"},"line_alpha":{"value":0.0},"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7360ef25-aa95-4010-85c5- ...

# %% [markdown]
# The results from the satellite data match well with the results from the tidal stations. The 'zig-zag' differences are near mean filled NaN-values, so that could be a possible explaination for these differences. The standard errors have the some order of magnitude, however the standard error is somewhat larger in the Waddensea.
#
# The satellite data are a nice addition to the tidal station data, also because they span a large area, instead of a few point sources. This can help in identifying causes of regional sea level changes. A downside is the relatively short time series for which they are available. This results in a large spread, so the uncertainty around the 'actual' trend is large. This makes extrapolation to the near future (a useful application for practical purposes) tricky.

# %% [markdown]
# ## Conclusions
# In this notebook possible sources for obtaining more data for the sea level monitor where explored. These extra data can subsequently be used to get a better view on regional differences in the speed with which the sea level rises.
#
# First the extra tide gauges available from PSMSL where considered. Three extra stations, Maassluis, West-terschelling en Roompot Buiten, are available in the official rlr-dataset. The first two are located closely to other RLR-stations, while the last has only a short timeseries. Adding these stations to the sea level monitor thus provides not much added value.
#
# A second source of extra data is the metric dataset available on PSMSL. The data from this dataset are however from worse quality (which is also clearly communicated by PSMSL) than the rlr monthly data. This makes the dataset less useful for practical purposes.
#
# A last source of data is satellite data available though AVISO altimetry. These data coincide reasonably well with the tidal gauge data, and are available for the complete Northsea (and world), with an resolution of a quarter degree longitude and latitide. The data are however available from 1993 on, which gives a large uncertainty around the trend. This makes it difficult to use it for short term predictions. The availability across the whole North Sea makes it however a good source for finding or checking sources of sea level rise differences.
