# %% [markdown]
# # Extending the number of data sources from tidal gauge stations and satellite data
#
# This notebooks explores different sources for extending the number of data sources for the sea level monitor. These extra sources can be used for getting a grip on regional differences in the speed with which the sea level rises.
#
# The primary source of the tidal data is the PSMSL website. This website receives the tide gauge data from Rijkswaterstaat. The notebook get-data can be used to obtain the data.

# %%
# Standard Python packages
import io
import os

# Python packages that need to be installed using pip or anaconda:
# For computations
import pandas
import numpy as np

# For GIS related function
import pyproj
from shapely.geometry import LineString, Point

# For loading netcdf
import netCDF4

# For plotting
import matplotlib.pyplot as plt
import bokeh.palettes
import bokeh.plotting
from bokeh.models import HoverTool

# Initialize modules for the jupyter notebook format
from nbformat import v4
# %matplotlib inline
bokeh.io.output_notebook()

# Disable pandas warnings
pandas.options.mode.chained_assignment = None
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb54b70e-2a6b-4921-a427-d22fb80c8104">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Define a function to read from functions from other notebooks

# %%
def execute_notebook(nbfile):
    """Function to run other notebook in this notebook"""
    with io.open(nbfile,encoding="utf8") as f:
        nb = v4.reads_json(f.read())
    
    ip = get_ipython()
    
    for cell in nb.cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.source)

# %% [markdown]
# A set of functions to get data is defined in the notebook 'get-data.py' We import this here.

# %%
execute_notebook('get-data.ipynb')

# %% [markdown]
# ## Extended station collection
#
# Currently the methods of the sea level monitor are applief on data of six tidal stations along the Dutch coast. For these stations the data is available via PSMSL, and the data are converted to RLR with NAP correction. There is however more data available from PSMSL, partly in RLR, and partly metric data (NAP). In the next section of this notebook, this data is retireved and compared to the 'official' data in the sea level monitor.

# %%
rlr6_stations = [
    'Vlissingen', 
    'Hoek van Holland', 
    'Den Helder', 
    'Delfzijl', 
    'Harlingen', 
    'IJmuiden'
]

rlr9_stations = rlr6_stations + [
    'Maassluis',
    'Roompot Buiten',
    'West-Terschelling'
]

rlr_data = get_station_data(dataset_name='rlr_monthly', coastline_code=150)
met_data = get_station_data(dataset_name='met_monthly', coastline_code=150)

met_stations = met_data['name'].squeeze().tolist()
# Out:
# found point 52.3799 3.75
# rlr_monthly 9 rlr
# rlr_monthly 20 rlr
# rlr_monthly 22 rlr
# rlr_monthly 23 rlr
# rlr_monthly 24 rlr
# rlr_monthly 25 rlr
# rlr_monthly 32 rlr
# rlr_monthly 236 rlr
# rlr_monthly 1551 rlr
# found point 52.3799 3.75
# met_monthly 9 met
# met_monthly 19 met
# met_monthly 20 met
# met_monthly 22 met
# met_monthly 23 met
# met_monthly 24 met
# met_monthly 25 met
# met_monthly 32 met
# met_monthly 35 met
# met_monthly 36 met
# met_monthly 236 met
# met_monthly 1331 met
# met_monthly 1507 met
# met_monthly 1551 met
# met_monthly 1837 met

# %% [markdown]
# Time series analysis of the gauge data, where the sea level y is described by a linear regression model with a trend, 18.6-year nodal cycle and the wind.

# %%
# Comments

colors = bokeh.palettes.Category20_15

stationsets = [
    [station.upper() for station in rlr6_stations],
    [station.upper() for station in rlr9_stations],
    met_data['name'].squeeze().tolist()
]

for stationset in stationsets:
    fig = bokeh.plotting.figure(
        x_range=(1840, 2020),
        plot_width=950,
        plot_height=450
    )
    
    for color, name in zip(colors, stationset):
        # Check if station is available in rlr set, otherwise use metric set
        if name in rlr_data['name'].values:
            station = rlr_data.set_index('name').loc[name]
            linestyle = 'solid'
        else:
            station = met_data.set_index('name').loc[name]
            linestyle = 'dashed'
        
        # Some series contain -9999, we set these values to nan
        station['data'].loc[(station['data']['height'] < -9000), 'height'] = np.nan
        
        # Select the data after 1890
        df = station['data'].loc[station['data'].year >= 1890]
        
        fit, names = linear_model(df, with_wind=False, with_season=False)
        
        fig.line(
            fit.model.exog[:, 1] + 1970,
            fit.predict() / 1e3,
            line_width=3,
            alpha=0.8,
            legend=station.name,
            color=color,
            line_dash=linestyle
        )

    fig.legend.location = "top_left"
    fig.yaxis.axis_label = 'Sea water level (m+NAP)'
    fig.xaxis.axis_label = 'Year'
    
    bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51b683ca-11cf-42f5-aa00-19054140b6ab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("51b683ca-11cf-42f5-aa00-19054140b6ab");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51b683ca-11cf-42f5-aa00-19054140b6ab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51b683ca-11cf-42f5-aa00-19054140b6ab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"da3dee26-cdf7-4655-882c-91394c0534fc":{"roots":{"references":[{"attributes":{"plot":{"id":"30e6ca29-334a-4c13-8def-bc171de82896","subtype":"Figure","type":"Plot"}},"id":"f1292583-a91d-4554-b0b6-37ae990f66b9","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a89f012-79bb-4214-a46b-b12841e38047","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e5c44aee-60b9-4504-9643-fda1df2eee5e","type":"Line"},{"attributes":{"plot":{"id":"30e6ca29-334a-4c13-8def-bc171de82896","subtype":"Figure","type":"Plot"}},"id":"10795c35-8199-4709-a9d9-0b1d68d6b223","type":"ResetTool"},{"attributes":{"plot":{"id":"30e6ca29-334a-4c13-8def-bc171de82896","subtype":"Figure","type":"Plot"}},"id":"dca1594b-b481-495c-b7f5-518804061ef1","type":"HelpTool"},{"attributes":{"label":{"value":"HARLINGEN"},"renderers":[{"id":"fdfb1045-a633-4af5-bd7f-8567f974f3ae","type":"GlyphRenderer"}]},"id":"b623662e-af11-4d26-b2e8-b64b19128eaa","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#ff7f0e"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"ffada0c4-b552-4a84-98b6-8208b2f15221","type":"Line"},{"attributes":{"label":{"value":"DEN HELDER"},"renderers":[{"id":"876ef518-930d-4993-aa33-24c55c6d4bdf","type":"GlyphRenderer"}]},"id":"0b67254f-70d0-4e6c-8511-9a80d84e5e1a","type":"LegendItem"},{"attributes":{"axis_label":"Sea water level (m+NAP)","formatter":{"id":"337944ed-1212-4582-8ac3-7270415b351b","type":"BasicTickFormatter"},"plot":{"id":"30e6ca29-334a-4c13-8def-bc171de82896","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a17f322-3d74-417b-947c-15b1b8aa83a7","type":"BasicTicker"}},"id":"0f9e9eeb-0040-4ce0-abd1-357eb05aa4bb","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3917e296-db32-4765-82b7-9d424be9306f","type":"ColumnDataSource"},"glyph":{"id":"ffada0c4-b552-4a84-98b6-8208b2f15221","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"
type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[444]},"y":{"__ndarray__":"...","dtype":"float64","shape":[444]}}},"id":"378c9e2e-da8a-4b98-8823-3581bf854324","type":"ColumnDataSource"},{"attributes":{"label":{"value":"HOEK VAN HOLLAND"},"renderers":[{"id":"eeaf2b99-6bf8-439e-ba73-d818d2bb1a6a","type":"GlyphRenderer"}]},"id":"b4550d93-4828-4b9c-99dd-92217384faa2","type":"LegendItem"},{"attributes":{"data_source":{"id":"007c51ee-e732-44b0-9250-e0b0396f8179","type":"ColumnDataSource"},"glyph":{"id":"4563d964-9ab1-4ec2-98ab-266614d74d37","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2874effa- ...

# %% [markdown]
# The top figure contains the fitted sea level trends for the 6 stations that are currently used in the sea level monitor. All series are part of the RLR monthly dataset from PSMSL.
#
# The second figure adds 3 other stations that are also present in the RLR monlthy set from PSMSL. Note that Roomput-Buiten is a very short series, since the station is installed after constructing the Eastern Scheldt storm surge barrier. The standard error around this trend is therefor larger than around the other stations, which is discussed later.
#
# The last figure contains another 6 extra stations, that are in the metric monthly dataset (the dashes lines). The quality of this data is worse, such that PSMSL advices: "in general we highly recommend that you do not use these records". For this exploratory study we do use the data, but keep the advice in mind. The trends from these stations are visually less consistent than the first 6 or 9 trends. Partly due to the shorter series (Frederikse et al. (2016) says at least a 60 year record is needed to detect a 2 mm/year trend), but likely also due to to the worse data quality of the metric monthly data set.

# %% [markdown]
# ## Differences along the Dutch coast
#
# In the next step, the linear model will be used to determine regional differences along the Dutch coast. To do so, every station along the dutch coast is projects on a line along the coast. The coefficient of the linear trend component, as well as the standard error in this coefficient are used to show the speed of the sea level rise along the coast.

# %%
crds = [
    (12000, 377000),
    (12000, 378000),
    (20407, 397159),
    (87784, 468350),
    (111514, 554797),
    (189909, 600139),
    (263643, 607342),
    (264643, 607342)
]

WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

kustlijn = LineString(crds)

# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'met', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=met_data['name'].values.tolist())

for station_data, tag in zip([rlr_data, met_data], ['rlr', 'met']):
    for name, station in station_data.iterrows():
        # Select the data from 1890 till now
        df = station['data'].loc[station['data'].year >= 1890]
        # Fit the linear model with wind
        fit, names = linear_model(df, with_wind=False, with_season=False)
        # Get the summary
        smry = fit.summary2(xname=names)
        # Determine the coefficient and standard error from the tables, and add to dataframe
        trend_values.loc[station['name'], (tag, 'coeff')] = float(smry.tables[1].values[1, 0])
        trend_values.loc[station['name'], (tag, 'stderr')] = float(smry.tables[1].values[1, 1])
        station_data.loc[name, 'trend_coef'] = float(smry.tables[1].values[1, 0])
        station_data.loc[name, 'trend_stderr'] = float(smry.tables[1].values[1, 1])

        # Project the station on the coast line, to determine the projected distance
        station_data.loc[name, 'proj_distance'] = kustlijn.project(
            Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
        )

    # Sort the station data by projected distance for plotting
    station_data.sort_values(by='proj_distance', inplace=True)

# %%
names = ['RLR6', 'RLR9', 'Metric']

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'green', 'orange']
source = {}

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    station_data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    station_data = station_data.set_index('name').reindex(stationset)
    station_data.sort_values(by='proj_distance', inplace=True)
    
    dist = station_data['proj_distance'].values
    
    source[name] = station_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance']]
    source[name]['proj_distance'] /= 1000
    source[name]['dataset'] = name
    
    # Add

    # Draw the sea level trend
    fig.line(dist / 1000, station_data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = station_data['trend_coef'].values - station_data['trend_stderr'].values
    upper = station_data['trend_coef'].values + station_data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]] / 1000,
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2, 
        line_alpha=0.0
    )


fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf8f77ec-8970-4dd0-9e28-1b94c2a8a830"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bf8f77ec-8970-4dd0-9e28-1b94c2a8a830");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf8f77ec-8970-4dd0-9e28-1b94c2a8a830");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf8f77ec-8970-4dd0-9e28-1b94c2a8a830' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"719f40af-9a36-4720-b9c4-4093aa287102":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"92af2f5b-b960-48a1-a073-e3671d803b4d","type":"PanTool"},{"id":"818bc205-50b2-4a14-9d3a-5673607daa81","type":"WheelZoomTool"},{"id":"a317a008-a096-4d6c-95c9-6309df9f9237","type":"BoxZoomTool"},{"id":"20712399-0831-4363-ba28-f5cc80d54c4d","type":"SaveTool"},{"id":"77a2ae62-d603-4e36-8b70-98f54b4dba72","type":"ResetTool"},{"id":"b76a51db-adad-4862-b0e8-46c1781975da","type":"HelpTool"},{"id":"ebd301b7-c83e-43b4-8228-4448c3c53f25","type":"HoverTool"}]},"id":"592abf6b-6bdc-4157-a6b3-141753495034","type":"Toolbar"},{"attributes":{"callback":null},"id":"3fd4ef25-2daa-4a3e-b26f-18208f48203c","type":"DataRange1d"},{"attributes":{"plot":{"id":"bbb6a37e-7c5c-4d7c-a2e8-140aa46d36fa","subtype":"Figure","type":"Plot"}},"id":"77a2ae62-d603-4e36-8b70-98f54b4dba72","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"proj_distance"},"y":{"field":"trend_coef"}},"id":"c4a29d1c-0323-4ac4-8153-0324bbc22f1b","type":"Circle"},{"attributes":{"plot":{"id":"bbb6a37e-7c5c-4d7c-a2e8-140aa46d36fa","subtype":"Figure","type":"Plot"}},"id":"b76a51db-adad-4862-b0e8-46c1781975da","type":"HelpTool"},{"attributes":{"label":{"value":"Metric"},"renderers":[{"id":"48914dc8-8779-4518-bec4-91bb54d5f9a3","type":"GlyphRenderer"}]},"id":"e4e321a7-4028-4a9b-b308-54c1a2331dae","type":"LegendItem"},{"attributes":{"data_source":{"id":"c30130b5-0a9a-4859-9a38-78eb4c3eb120","type":"ColumnDataSource"},"glyph":{"id":"74449f1b-cb10-433f-90a6-06a126a5923d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c4a29d1c-0323-4ac4-8153-0324bbc22f1b","type":"Circle"},"selection_glyph":null},"id":"fd04ab27-bed0-4faf-9920-1cd7ab6c077b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"Ubm+DwsPLkCrIhBYkmlDQD1DbXkRbklA2SJQKQTTS0CHnYt72yhNQF6oaqcYzFBAtnJrPWgvUkBS+9u0RQFTQP5QZ4b0JlZAm8lOJUttVkC6+pBWbttiQK4wzvmPBWpAAJtlNvMucEA7bvIrdTZwQExdk0K+9XZA","dtype":"float64","shape":[15]},"y":{"__ndarray__":"6swpAIR2AECx0Yc2A571PyRhYf1guP8/H3YEDpcF/j9q2CiiljH/P9RmWage+ARA7pSGRbcADkBREOw2qb38P4nmfuqlKwJArIMgf1mC+j+VzRLahoIAQB72HAC3Xfc/f5ePbt4/8T+eoM39qVn1PzdrRW/bcf8/","dtype":"float64","shape":[15]}}},"id":"4aa440aa-5afe-4c4a-825d-2581a3d73910","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"3ec849ee-d4b6-4f21-aaaf-0306e56346d4","type":"Title"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"orange"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"066b0a3d-ef37-489d-841d-1fcddbad750c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3dee7861-fd90-4767-98a9-658d8ea2cb7d","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ba3db41-900d-43fb-9368-4e7749a97f88","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"Ubm+DwsPLkCrIhBYkmlDQP5QZ4b0JlZAm8lOJUttVkC6+pBWbttiQK4wzvmPBWpAAJtlNvMucEA7bvIrdTZwQExdk0K+9XZA","dtype":"float64","shape":[9]},"y":{"__ndarray__":"iqy5Sbp7AUB3IQ1ttC4GQNNQJy9yHwNACoPT9Ekk/D9RHZENYDkBQFbAe1PBhfg/fsoKyxaZ8z/B1SEgkNP1P6kVgZYr/f8/","dtype":"float64","shape":[9]}}},"id":"079758d6-b4ea-4b2a-9ea8-160496de3f92","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"263a8eaa-eaaa-4d24-83d5-6fe8fd6f06d1","type":"LegendItem"},{"id":"d72938be-d7ae-4b22-a01d-0855558421d3","type":"LegendItem"},{"id":"e4e321a7-4028-4a9b-b308-54c1a2331dae","type":"LegendItem"}],"location":"top_left","plot":{"id":"bbb6a37e-7c5c-4d7c-a2e8-140aa46d36fa","subtype":"Figure","typ ...

# %%
names = ['RLR6', 'RLR9', 'Metric']
fig = bokeh.plotting.figure(x_range=(1885, 2020), plot_width=900, plot_height=400)
colors = ['blue', 'green', 'orange']

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    data = data.set_index('name').reindex(stationset)
    
    # compute the mean for metric data
    grouped = pandas.concat(data['data'].dropna().tolist()).reset_index()[['year', 't', 'height', 'u', 'v', 'u2', 'v2']].groupby(['year', 't'])
    mean = grouped.mean().reset_index()
    # filter out non-trusted part (before NAP)
    mean = mean[mean['year'] >= 1890].copy()
    linear_fit, names = linear_model(mean, with_wind=False, with_season=False)

    # Draw the sea level trend
    fig.line(
        linear_fit.model.exog[:, 1] + 1970, 
        linear_fit.predict() / 1000.,
        line_width=3, 
        legend=name, 
        color=color,
        alpha=0.5
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'year'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5fd801d-6176-4d3f-92ec-c2df525164b9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f5fd801d-6176-4d3f-92ec-c2df525164b9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5fd801d-6176-4d3f-92ec-c2df525164b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5fd801d-6176-4d3f-92ec-c2df525164b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d219b027-b53b-4990-ab9c-862848af6fb6":{"roots":{"references":[{"attributes":{},"id":"8bdd3503-35fa-4c15-9947-d6f9e230aaf4","type":"BasicTicker"},{"attributes":{},"id":"f72b557e-8f2b-457e-8600-2a34e59b4828","type":"BasicTicker"},{"attributes":{"axis_label":"year","formatter":{"id":"e6a56004-955a-44a0-ba6c-324967eb610d","type":"BasicTickFormatter"},"plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"},"ticker":{"id":"8bdd3503-35fa-4c15-9947-d6f9e230aaf4","type":"BasicTicker"}},"id":"1441ef80-49e8-4243-89d6-78d24618bcb0","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"08769f99-e8bc-4346-899b-21e668a69914","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7ba971e-436a-437e-aa44-90b41c982746","type":"Line"},{"attributes":{"data_source":{"id":"f6f5571c-69b8-4b44-a692-1e1f5c84f2e0","type":"ColumnDataSource"},"glyph":{"id":"e7ba971e-436a-437e-aa44-90b41c982746","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2694d982-c993-4561-91ee-2f44ec457d85","type":"Line"},"selection_glyph":null},"id":"4d0b3091-866a-4ab9-b46f-45508face0d7","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"4aa584ae-64b6-4df2-85af-b7bc0552a75f","type":"Line"},{"attributes":{"plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"}},"id":"36250cc8-00e6-4b91-991a-dd69530d3cef","type":"ResetTool"},{"attributes":{},"id":"4261a5f9-b0ed-4000-a734-33376f2ca916","type":"ToolEvents"},{"attributes":{"items":[{"id":"5cc365d7-2a63-4bab-a4e8-f47af12ec27c","type":"LegendItem"},{"id":"aa086a55-91ef-46ad-b4b8-cbd6cc420df2","type":"LegendItem"},{"id":"d6d45eb5-cfb1-4670-acfa-08f8af47c6a6","type":"LegendItem"}],"location":"top_left","plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"}},"id":"144b17ab-a25a-4264-8d88-e8f1d81ad23e","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"},"ticker":{"id":"f72b557e-8f2b-457e-8600-2a34e59b4828","type":"BasicTicker"}},"id":"a46926f4-095a-4dcf-beb1-de18cc3c2afa","type":"Grid"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"27655069-6d8c-4dc4-8f37-ee8dd184521a","type":"GlyphRenderer"}]},"id":"aa086a55-91ef-46ad-b4b8-cbd6cc420df2","type":"LegendItem"},{"attributes":{"plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"}},"id":"ac5cee7c-5d9a-45c7-923d-234ed5f72e9b","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"deaa800d-06c4-468a-b09d-82585b8b0836","type":"ColumnDataSource"},"glyph":{"id":"b8820aef-0ba3-4abc-bb9d-37b9a86058cb","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"52ed78dd-0af1-4f68-9f07-87888337bb02","type":"Line"},"selection_glyph":null},"id":"27655069-6d8c-4dc4-8f37-ee8dd184521a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"69cfe291-fe23-457e-91e9-6ea68fc59008","subtype":"Figure","type":"Plot"}},"id":"400c76cc-59b9-4b8f-b740-a40c58152c95","type":"HelpTool"},{"attributes":{"label":{"value":"Metric"},"renderers":[{"id":"1fe8a951-9214-4ad3-a408-51a847fefa3d","type":"GlyphRenderer"}]},"id":"d6d45eb5-cfb1-4670-acfa-08f8af47c6a6","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"orange"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"70fb0dee-6aaa-4ed7-8fe1-7d5245a5638a","type":"Line"},{"attributes":{"callback":null,"end":2020,"start":1885} ...

# %% [markdown]
# First we compare the effects of adding the three extra stations for which the RLR data can be retrieved at PSMSL. The trends show a that adding the three stations gives higher values around 1900 and equal values around 2000. These differences can be explained by viewing the trends of the 3 extra stations. The addition of West-Terschelling and Roompot-Buiten gives lower values in the more recent part of the trend, while adding Maassluis raises the trend over the full range.
#
# We also compare the rlr data to the metric stations. The trend does not differ considerably from the RLR trends. However, as we saw before, many of the metric stations have a shorter time range for which the data are available. Also some of the 'metric stations' are located at a location not directly at the coast, but for example inside the Eastern Scheldt. The quality if these data is thus worse than the data of the rlr stations.
#
# The trends shown in the following table show that the uncertainty around the metric data is larger, while there is no clear added value in using the extra dataset.

# %%
trend_values.dropna(how='all', axis=1)
# Out:
#                          rlr                 met
#                        coeff     stderr    coeff     stderr
# MAASSLUIS            1.75886  0.0658508  1.65682  0.0660107
# HELLEVOETSLUIS           NaN        NaN   1.7963   0.136059
# VLISSINGEN           2.18541  0.0578705  2.05787  0.0579419
# HOEK VAN HOLLAND     2.39035  0.0633809  2.27131    0.06365
# DEN HELDER           1.53266  0.0762018  1.46038  0.0761841
# DELFZIJL             1.99931  0.0875263   1.9653  0.0874793
# HARLINGEN            1.36415  0.0903553  1.33439  0.0902468
# IJMUIDEN             2.15302  0.0723758  2.06373   0.072524
# ZIERIKZEE                NaN        NaN  1.98251  0.0989713
# BROUWERSHAVEN            NaN        NaN  1.94961   0.125696
# WEST-TERSCHELLING    1.22488   0.126765  1.07809   0.126048
# STELLENDAM BUITEN        NaN        NaN  3.75035     1.0446
# BROUWERSHAVENSE GAT      NaN        NaN  1.87636   0.443555
# ROOMPOT BUITEN       2.77281   0.523072  1.35108   0.445708
# HARINGVLIET              NaN        NaN  2.62115   0.708255

# %% [markdown]
# ## Satellite data
#
# Next to the data from the tidal stations, there is also sea level data available from satellite observations. In this section of the notebook, we explore these data and compare them to the data from the tidal stations.

# %% [markdown]
# Now we load the satellite data from the netCDF4 file. First de latitude en longitude (axes) of the data are loaded, after which we use the data around the Dutch coast.

# %%
# Import sea level data (USER DEFINED LOCATION)
datafile = 'dt_global_merged_msla_h_merged.nc'
if not os.path.exists(datafile):
    raise OSError(f'"{datafile}" not found. Make sure you have the required data.')

ds = netCDF4.Dataset(datafile)

# Get longitude and latitude
lon = ds.variables['lon'][:]
lat = ds.variables['lat'][:]

# Determine relevant part
lon_selection = lon[(lon > 2) * (lon < 7)]
lat_selection = lat[(lat > 51) * (lat < 54.5)]

# Download sea level averages for relevant part
sla = ds.variables['sla'][:, np.in1d(lat, lat_selection), np.in1d(lon, lon_selection)]

# Get the time stamps of the 
time = netCDF4.num2date(ds.variables['time'][:], ds.variables['time'].units)

# %%
winddf = df[['u2', 'v2']].reset_index()
winddf['year'] = [row.t.year + row.t.month / 12. for row in winddf.itertuples()]

# %% [markdown]
# We apply the linear model with wind on the data:

# %%
# Load coorindate systems for transformation
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

# Empty list for appending satellite data per coordinate
satellite_data = []

# Loop trough points in relevant range
years = [time[i].year + time[i].month / 12. for i in range(len(time))]
coeff = np.zeros((len(lat_selection), len(lon_selection)))
error = np.zeros_like(coeff)

for i, x in enumerate(lon_selection):
    for j, y in enumerate(lat_selection):
        # Add data
        data = pandas.DataFrame(columns=['year', 'height'])
        data['year'] = years
        data['height'] = sla[:, j, i]
        data = data.merge(winddf, on='year')
        
        # Skip the coordinate if it is masked
        if any(sla[:, j, i].mask):
            coeff[j, i] = np.nan
            error[j, i] = np.nan
            continue            
        
        # Fit model
        fit, names = linear_model(data, with_wind=True, with_season=False)
        smry = fit.summary2(xname=names)
        
        # Add to list
        trend_coef = float(smry.tables[1].values[1, 0])
        trend_stderr = float(smry.tables[1].values[1, 1])
        satellite_data.append([x, y, trend_coef, trend_stderr, data])
        
        # Add to 2d-arrays
        coeff[j, i] = trend_coef
        error[j, i] = trend_stderr
        
satellite_data = pandas.DataFrame(
    satellite_data,
    columns=['lon', 'lat', 'trend_coef', 'trend_stderr', 'data']
)

# %%
xy = np.loadtxt('landboundary.txt')
fig, ax = plt.subplots(figsize=(16/2.54, 13/2.54))

xy = pyproj.transform(RD, WGS84, *xy.T)

ax.plot(*xy, color='0.9', lw=1.0)
ax.plot(*rlr_data[['lon', 'lat']].values.T, marker='.', color='C3', ls='', ms=7, label='Tide gauges')
ax.legend(fancybox=False, loc='lower right', fontsize=8)

lon_step = lon_selection[1] - lon_selection[0]
lat_step = lat_selection[1] - lat_selection[0]

ws = (min(lon_selection) - 0.5 * lon_step, min(lat_selection) - 0.5 * lat_step)
en = (max(lon_selection) + 0.5 * lon_step, max(lat_selection) + 0.5 * lat_step)
im = ax.imshow(
    coeff*1000,
    extent=(ws[0], en[0], ws[1], en[1]),
    origin='lower',
    aspect=1.5
)
ax.set_xlabel('Longitude', fontsize=8)
ax.set_ylabel('Latitude', fontsize=8)

cb = plt.colorbar(im)
cb.set_label('Sea level rise [mm/year]', fontsize=8)

fig.savefig('slr_satellite.pdf')

# %% [markdown]
# We compare this data to the tidal gauge data. To do so, we interpolate the coastline on which we projected the gauges earlier on in the satellite data. Note that for this interpolation the NaN values are filled with the mean of the values in the researched area. This can affect the result for locations close to the white parts in the figure above.

# %%
from scipy.interpolate import interp2d

# Fill copies of the 2d-arrays with average values at the position of the NaN's
coeff_notnull = coeff.copy()
coeff_notnull[np.isnan(coeff_notnull)] = np.nanmean(coeff)
error_notnull = error.copy()
error_notnull[np.isnan(error_notnull)] = np.nanmean(error)

# Define interpolation function
f_coeff = interp2d(lon_selection, lat_selection, coeff_notnull, kind='linear')
f_error = interp2d(lon_selection, lat_selection, error_notnull, kind='linear')

# Define a grid for plotting
dist = np.linspace(0, kustlijn.length, 200)

# Interpolate coordinaties along the coastline
xy = np.vstack([pyproj.transform(RD, WGS84, *kustlijn.interpolate(i).coords[0]) for i in dist])
z_coeff = np.array([f_coeff(x, y)[0] for x, y in xy]) * 1000
z_error = np.array([f_error(x, y)[0] for x, y in xy]) * 1000

# Draw the sea level trend
fig = bokeh.plotting.figure(
    x_range=(0, max(dist)/1000),
    y_range=(0, 5.0),
    plot_width=900,
    plot_height=400
)

fig.line(
    dist/1000,
    z_coeff, 
    line_width=3,
    legend='coefficient of linear trend', 
    color='blue', 
    alpha=0.5
)

fig.patch(
    np.r_[dist, dist[::-1]]/1000,
    np.r_[z_coeff-z_error, (z_coeff+z_error)[::-1]], 
    color='blue', 
    fill_alpha=0.2, 
    line_alpha=0.2, 
    legend='std error interval of linear trend'
)

fig.legend.location = "bottom_left"
fig.xaxis.axis_label = 'Distance along coast [km]'
fig.yaxis.axis_label = 'Sea level rise per year [mm] (trend)'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="70bfb08f-1a6f-4588-b083-c467f8a49e07"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("70bfb08f-1a6f-4588-b083-c467f8a49e07");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70bfb08f-1a6f-4588-b083-c467f8a49e07");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70bfb08f-1a6f-4588-b083-c467f8a49e07' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5872de83-8776-4463-8d22-0b14dc745a68":{"roots":{"references":[{"attributes":{"data_source":{"id":"1f8e0a30-6c4d-4a16-9a4c-e092df032514","type":"ColumnDataSource"},"glyph":{"id":"3b7ad1cd-62b4-4594-b4ad-23b15c415dac","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a8667b3c-2a7f-4cd6-b510-940730478680","type":"Line"},"selection_glyph":null},"id":"930f623a-b7b2-43b8-b5aa-060669972062","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"5a18f507-0c52-4a61-a4ff-2101f4daed5e","type":"LinearAxis"}],"left":[{"id":"7702a226-098c-4153-b19b-37cf6f1a91b0","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":
type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b7705e12-ce3b-4488-a7cb-5725d261 ...

# %% [markdown]
# The first thing to be noted on this data is that the spread in this data is much larger. This is to be expected since the data is available since 1993, which is much shorter than the tidal data. The second thing to be noted is that the trend coefficient from the data is larger for the combination of satellite data and period, compared to the tidal data we showed before.
#
# To get a better view of the usability of satellite data for estimating the (regional) sea level rise speed along the Dutch coast, we compare equal periods for the sattelite data and the tidal data. We interpolate the locations of the tidal stations in the satellite data, to get the trend at the same location.

# %%
# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=rlr_data['name'].values.tolist())

# Determine the trends again for the rlr data
for name, station in rlr_data.iterrows():
    # Select the data from 1890 till now
    df = station['data'].loc[station['data'].year >= 1993]
    
    # Fit the linear model with wind
    fit, names = linear_model(df, with_wind=True, with_season=False)
    # Get the summary
    smry = fit.summary2(xname=names)
    # Determine the coefficient and standard error from the tables, and add to dataframe
    trend_coef = float(smry.tables[1].values[1, 0])
    trend_err = float(smry.tables[1].values[1, 1])
    station_data.loc[name, 'trend_coef'] = trend_coef
    station_data.loc[name, 'trend_stderr'] = trend_err
    trend_values.loc[station['name'], ('rlr', 'coeff')] = trend_coef
    trend_values.loc[station['name'], ('rlr', 'stderr')] = trend_err
    # Project the station on the coast line, to determine the projected distance
    station_data.loc[name, 'proj_distance'] = kustlijn.project(
        Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
    )

# Sort the station data by projected distance for plotting
station_data.sort_values(by='proj_distance', inplace=True)

# Determine the trends for the satellite data at the locations of the rlr stations
# Interpolate the for all (nine) RLR stations
for _, station in rlr_data.iterrows():
    trend_values.loc[station['name'], ('satellite', 'coeff')] = f_coeff(*station[['lon', 'lat']].values)[0] * 1000
    trend_values.loc[station['name'], ('satellite', 'stderr')] = f_error(*station[['lon', 'lat']].values)[0] * 1000

# %%
names = ['RLR9', 'Satellite']
pandas.options.mode.chained_assignment = None

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(y_range=(0, 5.5), plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'orange']
source = {}

# Loop trough the different datasets to be plotted
dist = rlr_data['proj_distance'].values

source['RLR9'] = rlr_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance', 'name']]
source['RLR9']['proj_distance'] /= 1000
source['RLR9']['dataset'] = 'RLR9'
source['RLR9']['trend_coef'] = np.nan
source['RLR9']['trend_stderr'] = np.nan
source['RLR9'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['RLR9']['name'], 'rlr'].values

source['Satellite'] = rlr_data[['lat', 'lon', 'proj_distance', 'name']]
source['Satellite']['proj_distance'] /= 1000
source['Satellite']['dataset'] = 'Satellite'
source['Satellite']['trend_coef'] = np.nan
source['Satellite']['trend_stderr'] = np.nan
source['Satellite'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['Satellite']['name'], 'satellite'].values
    
for name, color in zip(names, colors):
    
    data = source[name]
    
    # Draw the sea level trend
    fig.line(dist/1000, data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = data['trend_coef'].values - data['trend_stderr'].values
    upper = data['trend_coef'].values + data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]]/1000, 
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2,
        line_alpha=0.0
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Linear trend coefficient (mm/year)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="19a00aab-a654-4c0b-96a1-9807b50212d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("19a00aab-a654-4c0b-96a1-9807b50212d2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("19a00aab-a654-4c0b-96a1-9807b50212d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '19a00aab-a654-4c0b-96a1-9807b50212d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fda68707-249f-4bda-b904-7b486e03fa8b":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"orange"},"line_alpha":{"value":0.5},"line_color":{"value":"orange"},"size":{"units":"screen","value":7},"x":{"field":"proj_distance"},"y":{"field":"trend_coef"}},"id":"ebc715e5-2a00-408d-ba95-c4dda95139d4","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"191182ca-f747-4d2d-98ca-ad6feec69cbe","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1bf83d6a-7646-4e9b-ae85-580dcce70798","type":"Patch"},{"attributes":{},"id":"7dfa6692-b989-4708-b2c2-0cd485770ffa","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"96616b5c-c27e-4111-904d-45787566f7d5","type":"Line"},{"attributes":{"data_source":{"id":"19cdc342-a3df-4d43-8d77-a5365afa54d8","type":"ColumnDataSource"},"glyph":{"id":"ebc715e5-2a00-408d-ba95-c4dda95139d4","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"600be768-32f0-4845-bc2d-db7a7408e07b","type":"Circle"},"selection_glyph":null},"id":"b81589e5-55fa-4118-b004-6244c0cc9321","type":"GlyphRenderer"},{"attributes":{},"id":"5bd102bc-8a36-4c02-ac62-7fceff89b429","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"Ubm+DwsPLkCrIhBYkmlDQP5QZ4b0JlZAm8lOJUttVkC6+pBWbttiQK4wzvmPBWpAAJtlNvMucEA7bvIrdTZwQExdk0K+9XZA","dtype":"float64","shape":[9]},"y":{"__ndarray__":"AOeCsh43D0CkNXTXuHcOQD0gNpg+AAZApkDOzFKECECbbKuhcykGQIL0v/sYkglAIXG5eZSQD0DsHaZCKoYNQA0qt/A6TApA","dtype":"float64","shape":[9]}}},"id":"4f555156-6e58-4732-9d81-bd6f3947163c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3f05dd66-79b0-49e4-865e-6a1136f3c5c1","type":"ColumnDataSource"},"glyph":{"id":"96616b5c-c27e-4111-904d-45787566f7d5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d0d05c13-f656-4672-928e-97c7247f1928","type":"Line"},"selection_glyph":null},"id":"6c6c87b3-6ec5-4385-bfa6-a9a2f643854e","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"ecb0e2b1-af99-4b17-a962-29aa6160e015","type":"LinearAxis"}],"left":[{"id":"fd5e15be-65dd-40c7-a653-055db3545616","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"ecb0e2b1-af99-4b17-a962-29aa6160e015","type":"LinearAxis"},{"id":"f9224ee9-50d1-4378-b029-95b8e229b984","type":"Grid"},{"id":"fd5e15be-65dd-40c7-a653-055db3545616","type":"LinearAxis"},{"id":"08264212-07fc-44ce-8c58-802bbbd59e19","type":"Grid"},{"id":"6bb2a452-facd-457a-952e-dc150aecd6cb","type":"BoxAnnotation"},{"id":"5342e38a-4454-4580-8c08-8564d7dc658e","type":"Legend"},{"id":"6c6c87b3-6ec5-4385-bfa6-a9a2f643854e","type":"GlyphRenderer"},{"id":"5ee07ee8-0ecb-4236-bb7d-7850b8ce8fde","type":"GlyphRenderer"},{"id":"930edbae-3ad9-4b21-afaa-8844eb9aac46","type":"GlyphRenderer"},{"id":"fd0e7a76-c03d-46bb-ac94-1e088bbaae9e","type":"GlyphRenderer"},{"id":"b81589e5-55fa-4118-b004-6244c0cc9321","type":"GlyphRenderer"},{"id":"bcb6a699-e2ca-4a5f-a13d-06cdcf96bb36","type":"GlyphRenderer"}],"title":{"id":"191182ca-f747-4d2d-98ca-ad6feec69cbe","type":"Title"},"tool_events":{"id":"fabeb7a5-9e31-47a5-8b1c-013a498e8b97","type":"ToolEvents"},"toolbar":{"id":"b4040360-97b2-43ee-ac09-a23eab0000c6","type":"Toolbar"},"x_range":{"id":"05e869a3-5858-44ce-bc27-dbeffab5a4c2","type":"DataRange1d"},"y_range":{"id":"73338a95-cf64-43d4-8adc-89d617b4dcf8","type":"Range1d"}},"id":"f4ff379a-ae07-4a43-8049-7f450677f2db","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"f4ff379a-ae07-4a43-8049-7f450677f2db","subtype":"Figure","type":"Plot"}},"id":"3035666a-b37a-40f9-bdbc-7150a150acde","type":"ResetTool"},{"attributes":{"callback":null,"end":5.5},"id":"73338a95-cf64-43d4-8adc-89d617b4dcf8","type":"Ra ...

# %% [markdown]
# The results from the satellite data match well with the results from the tidal stations. The 'zig-zag' differences are near mean filled NaN-values, so that could be a possible explaination for these differences. The standard errors of the RLR data are slightly lower than the errors of the satellite data.
#
# The satellite data are a nice addition to the tide gauge data, also because they span a large area, instead of a few point sources. This can help in identifying causes of regional sea level changes. A downside is the relatively short time series for which they are available. This results in a large spread, so the uncertainty around the 'actual' trend is large. This makes extrapolation to the near future (a useful application for practical purposes) tricky.

# %% [markdown]
# ## Conclusions
# In this notebook possible sources for obtaining more data for the sea level monitor where explored. These extra data can subsequently be used to get a better view on regional differences in the speed with which the sea level rises.
#
# First the extra tide gauges available from PSMSL where considered. Three extra stations, Maassluis, West-terschelling en Roompot Buiten, are available in the official rlr-dataset. The first two are located closely to other RLR-stations, while the last has only a short timeseries. Adding these stations to the sea level monitor thus provides not much added value.
#
# A second source of extra data is the metric dataset available on PSMSL. The data from this dataset are however from worse quality (which is also clearly communicated by PSMSL) than the rlr monthly data. This makes the dataset less useful for practical purposes.
#
# A last source of data is satellite data available though AVISO altimetry. These data coincide reasonably well with the tidal gauge data, and are available for the complete Northsea (and world), with an resolution of a quarter degree longitude and latitide. The data are however available from 1993 on, which gives a large uncertainty around the trend. This makes it difficult to use it for short term predictions. The availability across the whole North Sea makes it however a good source for finding or checking sources of sea level rise differences.
