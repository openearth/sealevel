# %% [markdown]
# # Extending the number of data sources from tidal gauge stations and satellite data
#
# This notebooks explores different sources for extending the number of data sources for the sea level monitor. These extra sources can be used for getting a grip on regional differences in the speed with which the sea level rises.
#
# The primary source of the tidal data is the PSMSL website. This website receives the tide gauge data from Rijkswaterstaat. The notebook get-data can be used to obtain the data.

# %%
# Standard Python packages
import io

# Python packages that need to be installed using pip or anaconda:
# For computations
import pandas
import numpy as np

# For GIS related function
import pyproj
from shapely.geometry import LineString, Point

# For loading netcdf
import netCDF4

# For plotting
import matplotlib.pyplot as plt
import bokeh.palettes
import bokeh.plotting
from bokeh.models import HoverTool

# Initialize modules for the jupyter notebook format
from nbformat import current
# %matplotlib inline
bokeh.io.output_notebook()

# Disable pandas warnings
pandas.options.mode.chained_assignment = None
# Out:
# C:\Anaconda3\lib\site-packages\nbformat\current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c1ca2619-1047-487f-84fc-efdba248cb9b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Define a function to read from functions from other notebooks

# %%
def execute_notebook(nbfile):
    """Function to run other notebook in this notebook"""
    with io.open(nbfile,encoding="utf8") as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)

# %% [markdown]
# A set of functions to get data is defined in the notebook 'get-data.py' We import this here.

# %%
execute_notebook('get-data.ipynb')

# %% [markdown]
# ## Extended station collection
#
# Currently the methods of the sea level monitor are applief on data of six tidal stations along the Dutch coast. For these stations the data is available via PSMSL, and the data are converted to RLR with NAP correction. There is however more data available from PSMSL, partly in RLR, and partly metric data (NAP). In the next section of this notebook, this data is retireved and compared to the 'official' data in the sea level monitor.

# %%
rlr_stations = [
    'Vlissingen', 
    'Hoek van Holland', 
    'Den Helder', 
    'Delfzijl', 
    'Harlingen', 
    'IJmuiden'
]

met_stations = rlr_stations + [
    'Maassluis',
    'Roompot Buiten',
    'West-Terschelling'
]

rlr_data = get_station_data(dataset_name='rlr_monthly', coastline_code=150, names=rlr_stations)
met_data = get_station_data(dataset_name='met_monthly', coastline_code=150, names=met_stations)
# Out:
# found point 52.3799 3.75
# rlr_monthly 20 rlr
# rlr_monthly 22 rlr
# rlr_monthly 23 rlr
# rlr_monthly 24 rlr
# rlr_monthly 25 rlr
# rlr_monthly 32 rlr
# found point 52.3799 3.75
# met_monthly 9 met
# met_monthly 20 met
# met_monthly 22 met
# met_monthly 23 met
# met_monthly 24 met
# met_monthly 25 met
# met_monthly 32 met
# met_monthly 236 met
# met_monthly 1551 met

# %% [markdown]
# Time series analysis of the gauge data, where the sea level y is described by a linear regression model with a trend, 18.6-year nodal cycle and the wind.

# %%
# Comments

colors = bokeh.palettes.Category20_15

stationsets = [
    [station.upper() for station in rlr_stations],
    [station.upper() for station in met_stations],
    met_data['name'].squeeze().tolist()
]

for stationset in stationsets:
    fig = bokeh.plotting.figure(
        x_range=(1840, 2020),
        plot_width=950,
        plot_height=450
    )
    
    for color, name in zip(colors, stationset):
        # Check if station is available in rlr set, otherwise use metric set
        if name in rlr_data['name'].values:
            station = rlr_data.set_index('name').loc[name]
            linestyle = 'solid'
        else:
            station = met_data.set_index('name').loc[name]
            linestyle = 'dashed'
        
        # Some series contain -9999, we set these values to nan
        station['data'].loc[(station['data']['height'] < -9000), 'height'] = np.nan
        
        # Select the data after 1890
        df = station['data'].loc[station['data'].year >= 1890]
        
        fit, names = linear_model(df, with_wind=False, with_season=False)
        
        fig.line(
            fit.model.exog[:, 1] + 1970,
            fit.predict() / 1e3,
            line_width=3,
            alpha=0.8,
            legend=station.name,
            color=color,
            line_dash=linestyle
        )

    fig.legend.location = "top_left"
    fig.yaxis.axis_label = 'Sea water level (m+NAP)'
    fig.xaxis.axis_label = 'Year'
    
    bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="309fa579-7d10-45e1-b4dd-1cbed9dc0769"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("309fa579-7d10-45e1-b4dd-1cbed9dc0769");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("309fa579-7d10-45e1-b4dd-1cbed9dc0769");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '309fa579-7d10-45e1-b4dd-1cbed9dc0769' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"079ad5f5-b331-4f0a-a9ca-a5118f3dd402":{"roots":{"references":[{"attributes":{},"id":"c87030dd-7357-4f94-b1ff-dc8839f583ad","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#98df8a"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ddeda6f-9a44-4200-8454-2135c45ceed8","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"95a2760a-4703-4f16-959c-fc5b93d08390","type":"Line"},{"attributes":{"callback":null,"end":2020,"start":1840},"id":"a985a3a7-9874-46f4-ad73-eed171834ad0","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ee07308-eb79-400a-b044-baa0c8f56c1b","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"20191a70-08bd-4024-a0cb-28220366640d","type":"PanTool"},{"id":"c5369354-529c-4d99-9a02-da0e8ebf9fec","type":"WheelZoomTool"},{"id":"f4906432-d4bf-4962-96bd-8d26c35d66bb","type":"BoxZoomTool"},{"id":"a0e46e48-df12-46a9-bf07-46b110433ddb","type":"SaveTool"},{"id":"758d094b-1cf3-4387-af5c-ed23d4ddd66f","type":"ResetTool"},{"id":"174f6137-87d7-4868-91e5-4ab7c69d0432","type":"HelpTool"}]},"id":"1fb56873-bf29-4abe-ba22-97b0a9bd457f","type":"Toolbar"},{"attributes":{},"id":"51c6c685-9ed3-42a2-8fb4-98a0b259b5ca","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6fd91d7c-7b0c-48ad-9cee-0b52a8a717aa","type":"ColumnDataSource"},"glyph":{"id":"5752ed25-e3dc-499a-88d2-845b897514b7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"95a2760a-4703-4f16-959c-fc5b93d08390","type":"Line"},"selection_glyph":null},"id":"3599559a-79fd-4d9d-9c52-8f1bc54ed332","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"6aa617bc-1f07-4b23-b09b-b0acbb24650a","type":"Line"},{"attributes":{"plot":{"id":"ce5eb90d-1a9a-4065-829d-0b38393ff2b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"51c6c685-9ed3-42a2-8fb4-98a0b259b5ca","type":"BasicTicker"}},"id":"f7270a7a-c698-4b90-84b6-ca9cc7bf41e0","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1536]},"y":{"__ndarray__":"...","dtype":"float64","shape":[
type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#ffbb78"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"808baa62-d84c-41eb-9546-bf0a98cbae6f","type":"Line"},{"attributes":{"data_source":{"id":"9269bc8e-1c64-48ef-997c-cccff00cd2ff","type":"ColumnDataSource"},"glyph":{"id":"6922b134-b825-4efe-823b-6dc08707ba6e","type":"Line"},"hover_glyph":null,"muted_glyph":nu ...

# %% [markdown]
# The top figure contains the fitted sea level trends for the 6 stations that are currently used in the sea level monitor. All series are part of the RLR monthly dataset from PSMSL.
#
# The second figure adds 3 other stations that are also present in the RLR monlthy set from PSMSL. Note that Roomput-Buiten is a very short series, since the station is installed after constructing the Eastern Scheldt storm surge barrier. The standard error around this trend is therefor larger than around the other stations, which is discussed later.
#
# The last figure contains another 6 extra stations, that are in the metric monthly dataset (the dashes lines). The quality of this data is worse, such that PSMSL advices: "in general we highly recommend that you do not use these records". For this exploratory study we do use the data, but keep the advice in mind. The trends from these stations are visually less consistent than the first 6 or 9 trends. Partly due to the shorter series (Frederikse et al. (2016) says at least a 60 year record is needed to detect a 2 mm/year trend), but likely also due to to the worse data quality of the metric monthly data set.

# %% [markdown]
# ## Differences along the Dutch coast
#
# In the next step, the linear model will be used to determine regional differences along the Dutch coast. To do so, every station along the dutch coast is projects on a line along the coast. The coefficient of the linear trend component, as well as the standard error in this coefficient are used to show the speed of the sea level rise along the coast.

# %%
crds = [
    (12000, 377000),
    (12000, 378000),
    (20407, 397159),
    (87784, 468350),
    (111514, 554797),
    (189909, 600139),
    (263643, 607342),
    (264643, 607342)
]
    
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

kustlijn = LineString(crds)

# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'met', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=met_data['name'].values.tolist())

for station_data, tag in zip([rlr_data, met_data], ['rlr', 'met']):
    for name, station in station_data.iterrows():
        # Select the data from 1890 till now
        df = station['data'].loc[station['data'].year >= 1890]
        # Fit the linear model with wind
        fit, names = linear_model(df, with_wind=False, with_season=False)
        # Get the summary
        smry = fit.summary2(xname=names)
        # Determine the coefficient and standard error from the tables, and add to dataframe
        trend_values.loc[station['name'], (tag, 'coeff')] = float(smry.tables[1].values[1, 0])
        trend_values.loc[station['name'], (tag, 'stderr')] = float(smry.tables[1].values[1, 1])
        station_data.loc[name, 'trend_coef'] = float(smry.tables[1].values[1, 0])
        station_data.loc[name, 'trend_stderr'] = float(smry.tables[1].values[1, 1])

        # Project the station on the coast line, to determine the projected distance
        station_data.loc[name, 'proj_distance'] = kustlijn.project(
            Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
        )

    # Sort the station data by projected distance for plotting
    station_data.sort_values(by='proj_distance', inplace=True)

# %%
names = ['RLR6', 'RLR9', 'Metric']

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'green', 'orange']
source = {}

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    station_data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    station_data = station_data.set_index('name').loc[stationset]
    station_data.sort_values(by='proj_distance', inplace=True)
    
    dist = station_data['proj_distance'].values
    
    source[name] = station_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance']]
    source[name]['proj_distance'] /= 1000
    source[name]['dataset'] = name
    
    # Add

    # Draw the sea level trend
    fig.line(dist / 1000, station_data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = station_data['trend_coef'].values - station_data['trend_stderr'].values
    upper = station_data['trend_coef'].values + station_data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]] / 1000,
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2, 
        line_alpha=0.0
    )


fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d556a864-154b-47c6-b77d-a1825e2b41f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d556a864-154b-47c6-b77d-a1825e2b41f1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d556a864-154b-47c6-b77d-a1825e2b41f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd556a864-154b-47c6-b77d-a1825e2b41f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a59ded58-5671-428e-86b7-6bf24105419a":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"be893632-397a-4cee-b40b-62b1a6faf7b1","type":"Line"},{"attributes":{"callback":null},"id":"0be034d9-53a6-4762-b9cc-ec6dcbbbab6f","type":"DataRange1d"},{"attributes":{},"id":"f12c0a12-84b8-4eff-8d5b-0e82d24fccc2","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"proj_distance"},"y":{"field":"trend_coef"}},"id":"acc5f369-35cb-4290-8560-e5ed1f8a467b","type":"Circle"},{"attributes":{"callback":null},"id":"345f06a1-1a27-443e-80d8-590920381e38","type":"DataRange1d"},{"attributes":{"data_source":{"id":"0ba3942d-e0e6-45e9-a5ed-92e102c7921c","type":"ColumnDataSource"},"glyph":{"id":"592e3f79-0f27-4bd8-aba9-d629e1accb3b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"acc5f369-35cb-4290-8560-e5ed1f8a467b","type":"Circle"},"selection_glyph":null},"id":"251d66fd-b7de-4d2e-8468-5c4ab40f2fca","type":"GlyphRenderer"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"8a4b7656-bf9a-44e0-b8b5-12faee4b3c2a","type":"GlyphRenderer"}]},"id":"93b8bf00-2311-45ab-b7ee-ab9f965b1e13","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2f86d44-2270-47b6-9c4d-19c2402da763","type":"Line"},{"attributes":{"axis_label":"Distance along coast","formatter":{"id":"62c83969-ec2e-4611-a947-adabed95fac0","type":"BasicTickFormatter"},"plot":{"id":"ef5b9fde-e49b-4120-9540-d8a45686cdeb","subtype":"Figure","type":"Plot"},"ticker":{"id":"00b8c567-d3a7-4059-838d-f3b8a3da2299","type":"BasicTicker"}},"id":"654d3dfe-dc6a-49e3-aba4-bad3fd1b9f27","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDiheeF9CZWQFKOPFZu22JATJd7+Y8FakCuH98rdTZwQJNak0K+9XZAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh/","dtype":"float64","shape":[9]},"y":{"__ndarray__":"gqy5Sbp7AUDUUCcvch8DQE4dkQ1gOQFATcB7U8GF+D/C1SEgkNP1P6sVgZYr/f8/AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh/","dtype":"float64","shape":[9]}}},"id":"3dcd8462-88bb-4726-9647-ae6fbf9a15bf","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDiheeF9CZWQFKOPFZu22JATJd7+Y8FakCuH98rdTZwQJNak0K+9XZAk1qTQr71dkCuH98rdTZwQEyXe/mPBWpAUo48Vm7bYkDiheeF9CZWQKjRgQoLDy5A","dtype":"float64","shape":[12]},"y":{"__ndarray__":"ZPJJfjUFAUCu0/VRpJ0CQM3pukMmpQBAk5iC8KFN9z/3Rwmzd2H0PxTBG5Kplv4/ITVzzdaxAECNYzqNqEX3PwfodLbgvfk/z1Bn15nNAUD6zVgMQKEDQKBmKRU/8gFA","dtype":"float64","shape":[12]}}},"id":"98e5b82c-5dbe-4001-b168-6b07b17fd20f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDgPQpXkmlDQOKF54X0JlZAEhHPJEttVkBSjjxWbttiQEyXe/mPBWpAyEpSNvMucECuH98rdTZwQJNak0K+9XZA","dtype":"float64","shape":[9]},"y":{"__ndarray__":"6swpAIR2AEC20Yc2A571P4jmfuqlKwJAsIMgf1mC+j+UzRLahoIAQBb2HAC3Xfc/kZePbt4/8T+eoM39qVn1PzZrRW/bcf8/","dtype":"float64","shape":[9]}}},"id":"f371c6c7-9ad6-4764-b580-364ffac63d62","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"blue"},"line_alpha":{"value":0.0},"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e49e439c-b12e-42a6-a3a5-4049b59e6dc3","type":"Patch"},{"attributes":{"label":{"value":"Metric"},"renderers":[{"id":"1366072c-f332-44b1-8a10-3233a98c428f","type":"GlyphRenderer"}]},"id":"d99aaf8d-35a7-49d7-b52f-367e40a5ce10","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"74d4ff6c-0d98-4405-9194-0624f5771f31"," ...

# %%
names = ['RLR6', 'RLR9', 'Metric']
fig = bokeh.plotting.figure(x_range=(1885, 2020), plot_width=900, plot_height=400)
colors = ['blue', 'green', 'orange']

# Loop trough the different datasets to be plotted
for name, stationset, color in zip(names, stationsets, colors):
    # Determine dataset
    data = rlr_data if 'rlr' in name.lower() else met_data
    
    # Select stations from station set
    data = data.set_index('name').loc[stationset]
    
    # compute the mean for metric data
    grouped = pandas.concat(data['data'].dropna().tolist()).reset_index()[['year', 't', 'height', 'u', 'v', 'u2', 'v2']].groupby(['year', 't'])
    mean = grouped.mean().reset_index()
    # filter out non-trusted part (before NAP)
    mean = mean[mean['year'] >= 1890].copy()
    linear_fit, names = linear_model(mean, with_wind=False, with_season=False)

    # Draw the sea level trend
    fig.line(
        linear_fit.model.exog[:, 1] + 1970, 
        linear_fit.predict() / 1000.,
        line_width=3, 
        legend=name, 
        color=color,
        alpha=0.5
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Average sea water level (m+NAP)'
fig.xaxis.axis_label = 'year'
bokeh.io.show(fig)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
type":"GlyphRenderer"},{"attributes":{"label":{"value":"Metric"},"renderers":[{"id":"f81f95d5-b059-4e2c-ac3b-6627c6846b4e","type":"GlyphRenderer"}]},"id":"72443e96-cfad-411f-83e1-66babb813909","type":"LegendItem"},{"attributes":{"label":{"value":"RLR9"},"renderers":[{"id":"5e4fd276-2ac8-4296-a173-1f568ed71572","type":"GlyphRenderer"}]},"id":"1ab7c981-0669-48ef-bc78-7ca0ec14242a","type":"LegendItem"},{"attributes":{"label":{"value":"RLR6"},"renderers":[{"id":"e713c88e-6345-4825-8baf-d02cdeb15cdb","type":"GlyphRenderer"}]},"id":"89a244f9-5f0c-4584-9243-514da801a9a5","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1536]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1536]}}},"id":"24a6d239-1b0b-4f5f-b32f-cf4efa375bbe","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"738b502a-da7f-4f58-be44-72bbf0df0b2b","subtype":"Figure","type":"Plot"}},"id":"a4a580ae-d2af-4fa8-a6f6-e605241f7ae9","type":"HelpTool"},{"attributes":{"below":[{"id":"9d7744cf-add6-4dc0-97a0-8797bf5fdce6","type":"LinearAxis"}],"left":[{"id":"ea0148d1-caff-42ec-8c27-c25314d58c07","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"9d7744cf-add6-4dc0-97a0-8797bf5fdce6","type":"LinearAxis"},{"id":"a68754fd-33b0-415d-b4e5-445a670b5888","type":"Grid"},{"id":"ea0148d1-caff-4 ...

# %% [markdown]
# First we compare the effects of adding the three extra stations for which the RLR data can be retrieved at PSMSL. The trends show a that adding the three stations gives higher values around 1900 and equal values around 2000. These differences can be explained by viewing the trends of the 3 extra stations. The addition of West-Terschelling and Roompot-Buiten gives lower values in the more recent part of the trend, while adding Maassluis raises the trend over the full range.
#
# We also compare the rlr data to the metric stations. The trend does not differ considerably from the RLR trends. However, as we saw before, many of the metric stations have a shorter time range for which the data are available. Also some of the 'metric stations' are located at a location not directly at the coast, but for example inside the Eastern Scheldt. The quality if these data is thus worse than the data of the rlr stations.
#
# The trends shown in the following table show that the uncertainty around the metric data is larger, while there is no clear added value in using the extra dataset.

# %%
trend_values.dropna(how='all', axis=1)
# Out:
#                        rlr                 met
#                      coeff     stderr    coeff     stderr
# MAASSLUIS              NaN        NaN  1.65682  0.0660107
# VLISSINGEN         2.18541  0.0578705  2.05787  0.0579419
# HOEK VAN HOLLAND   2.39035  0.0633809  2.27131    0.06365
# DEN HELDER         1.53266  0.0762018  1.46038  0.0761841
# DELFZIJL           1.99931  0.0875263   1.9653  0.0874793
# HARLINGEN          1.36415  0.0903553  1.33439  0.0902468
# IJMUIDEN           2.15302  0.0723758  2.06373   0.072524
# WEST-TERSCHELLING      NaN        NaN  1.07809   0.126048
# ROOMPOT BUITEN         NaN        NaN  1.35108   0.445708

# %% [markdown]
# ## Satellite data
#
# Next to the data from the tidal stations, there is also sea level data available from satellite observations. In this section of the notebook, we explore these data and compare them to the data from the tidal stations.

# %% [markdown]
# Now we load the satellite data from the netCDF4 file. First de latitude en longitude (axes) of the data are loaded, after which we use the data around the Dutch coast.

# %%
# Import sea level data (USER DEFINED LOCATION)
ds = netCDF4.Dataset(r"d:\Documents\2695.50 Zeespiegelstijging 2018\Data\dt_global_merged_msla_h_merged.nc")

# Get longitude and latitude
lon = ds.variables['lon'][:]
lat = ds.variables['lat'][:]

# Determine relevant part
lon_selection = lon[(lon > 2) * (lon < 7)]
lat_selection = lat[(lat > 51) * (lat < 54.5)]

# Download sea level averages for relevant part
sla = ds.variables['sla'][:, np.in1d(lat, lat_selection), np.in1d(lon, lon_selection)]

# Get the time stamps of the 
time = netCDF4.num2date(ds.variables['time'][:], ds.variables['time'].units)

# %% [markdown]
# We apply the linear model of the sea level data on the data:

# %%
# Load coorindate systems for transformation
WGS84 = pyproj.Proj(init='epsg:4326')
RD = pyproj.Proj(init='epsg:28992')

# Empty list for appending satellite data per coordinate
satellite_data = []

# Loop trough points in relevant range
years = [time[i].year + time[i].month / 12. for i in range(len(time))]
coeff = np.zeros((len(lat_selection), len(lon_selection)))
error = np.zeros_like(coeff)

for i, x in enumerate(lon_selection):
    for j, y in enumerate(lat_selection):
        # Add data
        data = pandas.DataFrame(columns=['year', 'height'])
        data['year'] = years
        data['height'] = sla[:, j, i]
        
        # Skip the coordinate if it is masked
        if any(sla[:, j, i].mask):
            coeff[j, i] = np.nan
            error[j, i] = np.nan
            continue            
        
        # Fit model
        fit, names = linear_model(data, with_wind=False, with_season=False)
        smry = fit.summary2(xname=names)
        
        # Add to list
        trend_coef = float(smry.tables[1].values[1, 0])
        trend_stderr = float(smry.tables[1].values[1, 1])
        satellite_data.append([x, y, trend_coef, trend_stderr, data])
        
        # Add to 2d-arrays
        coeff[j, i] = trend_coef
        error[j, i] = trend_stderr
        
satellite_data = pandas.DataFrame(
    satellite_data,
    columns=['lon', 'lat', 'trend_coef', 'trend_stderr', 'data']
)

# %%
xy = np.loadtxt(r'landboundary.txt')
fig, ax = plt.subplots(figsize=(16/2.54, 13/2.54))

xy = pyproj.transform(RD, WGS84, *xy.T)

ax.plot(*xy, color='0.9', lw=1.0)
ax.plot(*rlr_data[['lon', 'lat']].values.T, marker='.', color='C3', ls='', ms=7, label='Getijdestations')
ax.legend(fancybox=False, loc='lower right', fontsize=8)

lon_step = lon_selection[1] - lon_selection[0]
lat_step = lat_selection[1] - lat_selection[0]

ws = (min(lon_selection) - 0.5 * lon_step, min(lat_selection) - 0.5 * lat_step)
en = (max(lon_selection) + 0.5 * lon_step, max(lat_selection) + 0.5 * lat_step)
im = ax.imshow(
    coeff*1000,
    extent=(ws[0], en[0], ws[1], en[1]),
    origin='lower',
    aspect=1.5
)
ax.set_xlabel('Longitude', fontsize=8)
ax.set_ylabel('Latitude', fontsize=8)

cb = plt.colorbar(im)
cb.set_label('Sea level rise [mm/year]', fontsize=8)

fig.savefig(r"d:\Documents\2695.50 Zeespiegelstijging 2018\Rapportage\Rapportage 2018\figures\slr_satellite.pdf")

# %% [markdown]
# We compare this data to the tidal gauge data. To do so, we interpolate the coastline on which we projected the gauges earlier on in the satellite data. Note that for this interpolation the NaN values are filled with the mean of the values in the researched area. This can affect the result for locations close to the white parts in the figure above.

# %%
from scipy.interpolate import interp2d

# Fill copies of the 2d-arrays with average values at the position of the NaN's
coeff_notnull = coeff.copy()
coeff_notnull[np.isnan(coeff_notnull)] = np.nanmean(coeff)
error_notnull = error.copy()
error_notnull[np.isnan(error_notnull)] = np.nanmean(error)

# Define interpolation function
f_coeff = interp2d(lon_selection, lat_selection, coeff_notnull, kind='linear')
f_error = interp2d(lon_selection, lat_selection, error_notnull, kind='linear')

# Define a grid for plotting
dist = np.linspace(0, kustlijn.length, 200)

# Interpolate coordinaties along the coastline
xy = np.vstack([pyproj.transform(RD, WGS84, *kustlijn.interpolate(i).coords[0]) for i in dist])
z_coeff = np.array([f_coeff(x, y)[0] for x, y in xy]) * 1000
z_error = np.array([f_error(x, y)[0] for x, y in xy]) * 1000

# Draw the sea level trend
fig = bokeh.plotting.figure(
    x_range=(0, max(dist)/1000),
    y_range=(0, 5.0),
    plot_width=900,
    plot_height=400
)

fig.line(
    dist/1000,
    z_coeff, 
    line_width=3,
    legend='coefficient of linear trend', 
    color='blue', 
    alpha=0.5
)

fig.patch(
    np.r_[dist, dist[::-1]]/1000,
    np.r_[z_coeff-z_error, (z_coeff+z_error)[::-1]], 
    color='blue', 
    fill_alpha=0.2, 
    line_alpha=0.2, 
    legend='std error interval of linear trend'
)

fig.legend.location = "bottom_left"
fig.xaxis.axis_label = 'Distance along coast [km]'
fig.yaxis.axis_label = 'Sea level rise per year [mm] (trend)'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="03e569b9-3e22-42f3-896a-c28f2266ac5e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("03e569b9-3e22-42f3-896a-c28f2266ac5e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("03e569b9-3e22-42f3-896a-c28f2266ac5e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '03e569b9-3e22-42f3-896a-c28f2266ac5e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3676d5aa-7c59-4483-841d-91b4ed11e740":{"roots":{"references":[{"attributes":{"data_source":{"id":"55c8417d-4384-400b-a29f-634e0810648a","type":"ColumnDataSource"},"glyph":{"id":"f3b39d63-f3fd-4e2d-940e-111d8394fcfe","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d5828670-ac70-4d6c-9877-2a3cc9bb7e4f","type":"Line"},"selection_glyph":null},"id":"f9ee6049-2dbc-4a08-a634-9270c4d4db63","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"8d4139fb-7a22-4b4b-a47e-4e3bf6c2927d","type":"Title"},{"attributes":{},"id":"606e829a-10ab-42c5-b9f1-8d171dbbc7f0","type":"BasicTicker"},{"attributes":{"items":[{"id":"87480246-625b-4458-a479-ed6ab53b3a9c","type":"LegendItem"},{"id":"afba350a-165b-49d8-975b-c7921f479d2e","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"}},"id":"962cfa02-e75d-415d-8375-833779bae6e9","type":"Legend"},{"attributes":{"below":[{"id":"4d3f9c93-5af6-4ee3-8eb7-e8d50dc6a0cc","type":"LinearAxis"}],"left":[{"id":"385ea4c3-6bd1-4e2b-a1bc-5357fc35e7ce","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"4d3f9c93-5af6-4ee3-8eb7-e8d50dc6a0cc","type":"LinearAxis"},{"id":"8f98be37-c4ca-4dbf-b51d-c9092b8ce0d6","type":"Grid"},{"id":"385ea4c3-6bd1-4e2b-a1bc-5357fc35e7ce","type":"LinearAxis"},{"id":"c4ba2ff9-d20c-487c-883f-e48b4bdaf3d4","type":"Grid"},{"id":"8e4cdc12-64c9-4191-a7fe-75b023fbcc3c","type":"BoxAnnotation"},{"id":"962cfa02-e75d-415d-8375-833779bae6e9","type":"Legend"},{"id":"f9ee6049-2dbc-4a08-a634-9270c4d4db63","type":"GlyphRenderer"},{"id":"082c7174-9427-4f7e-b975-bc780c3e1557","type":"GlyphRenderer"}],"title":{"id":"8d4139fb-7a22-4b4b-a47e-4e3bf6c2927d","type":"Title"},"tool_events":{"id":"76362391-a80c-4e53-a3dc-1f14b6bd8c77","type":"ToolEvents"},"toolbar":{"id":"c7cc534a-002e-49d1-b767-3d2fb7a82913","type":"Toolbar"},"x_range":{"id":"0aced5db-31c7-4562-9374-d968c5d14bbf","type":"Range1d"},"y_range":{"id":"901fefab-3f2a-44de-8929-500ff155983a","type":"Range1d"}},"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":5.0},"id":"901fefab-3f2a-44de-8929-500ff155983a","type":"Range1d"},{"attributes":{"label":{"value":"coefficient of linear trend"},"renderers":[{"id":"f9ee6049-2dbc-4a08-a634-9270c4d4db63","type":"GlyphRenderer"}]},"id":"87480246-625b-4458-a479-ed6ab53b3a9c","type":"LegendItem"},{"attributes":{"plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"},"ticker":{"id":"322fb29d-c581-4d00-8663-0185909f9281","type":"BasicTicker"}},"id":"8f98be37-c4ca-4dbf-b51d-c9092b8ce0d6","type":"Grid"},{"attributes":{"plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"}},"id":"9ecbf667-4747-4f30-b153-584d3c2e2220","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"},"ticker":{"id":"606e829a-10ab-42c5-b9f1-8d171dbbc7f0","type":"BasicTicker"}},"id":"c4ba2ff9-d20c-487c-883f-e48b4bdaf3d4","type":"Grid"},{"attributes":{},"id":"4f66368c-6a75-48af-95b1-dea9bdf38dcd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"}},"id":"85372e46-5396-403f-a8f5-b8c622f0d459","type":"HelpTool"},{"attributes":{"overlay":{"id":"8e4cdc12-64c9-4191-a7fe-75b023fbcc3c","type":"BoxAnnotation"},"plot":{"id":"403b050c-a128-494c-81ad-b5b57171bcc0","subtype":"Figure","type":"Plot"}},"id":"94db6bb8-29f6-4c43-af33-8be50abfd26c","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8e4cdc12-64c9-4191-a7fe-75b023fbc ...

# %% [markdown]
# The first thing to be noted on this data is that the spread in this data is much larger. This is to be expected since the data is available since 1993, which is much shorter than the tidal data. The second thing to be noted is that the trend coefficient from the data is larger for the combination of satellite data and period, compared to the tidal data we showed before.
#
# To get a better view of the usability of satellite data for estimating the (regional) sea level rise speed along the Dutch coast, we compare equal periods for the sattelite data and the tidal data. We interpolate the locations of the tidal stations in the satellite data, to get the trend at the same location.

# %%
# Create dataframe with trend
columns = pandas.MultiIndex.from_product((['rlr', 'satellite'], ['coeff', 'stderr']))
trend_values = pandas.DataFrame(columns=columns, index=rlr_data['name'].values.tolist())

# Determine the trends again for the rlr data
for name, station in rlr_data.iterrows():
    # Select the data from 1890 till now
    df = station['data'].loc[station['data'].year >= 1993]
    
    # Fit the linear model with wind
    fit, names = linear_model(df, with_wind=False, with_season=False)
    # Get the summary
    smry = fit.summary2(xname=names)
    # Determine the coefficient and standard error from the tables, and add to dataframe
    trend_coef = float(smry.tables[1].values[1, 0])
    trend_err = float(smry.tables[1].values[1, 1])
    station_data.loc[name, 'trend_coef'] = trend_coef
    station_data.loc[name, 'trend_stderr'] = trend_err
    trend_values.loc[station['name'], ('rlr', 'coeff')] = trend_coef
    trend_values.loc[station['name'], ('rlr', 'stderr')] = trend_err
    # Project the station on the coast line, to determine the projected distance
    station_data.loc[name, 'proj_distance'] = kustlijn.project(
        Point(pyproj.transform(WGS84, RD, station['lon'], station['lat']))
    )

# Sort the station data by projected distance for plotting
station_data.sort_values(by='proj_distance', inplace=True)

# Determine the trends for the satellite data at the locations of the rlr stations
# Interpolate the for all (nine) RLR stations
for _, station in rlr_data.iterrows():
    trend_values.loc[station['name'], ('satellite', 'coeff')] = f_coeff(*station[['lon', 'lat']].values)[0] * 1000
    trend_values.loc[station['name'], ('satellite', 'stderr')] = f_error(*station[['lon', 'lat']].values)[0] * 1000

# %%
names = ['RLR9', 'Satellite']
pandas.options.mode.chained_assignment = None

hover = HoverTool(tooltips=[
    ("station", "@name"),
    ("dataset", "@dataset"),
    ("(lon,lat)", "(@lon, @lat)"),
    ("coef", "@trend_coef"),
    ("stderr", "@trend_stderr"),
])
    
fig = bokeh.plotting.figure(y_range=(0, 5.5), plot_width=900, plot_height=400)
fig.add_tools(hover)
colors = ['blue', 'orange']
source = {}

# Loop trough the different datasets to be plotted
dist = rlr_data['proj_distance'].values

source['RLR9'] = rlr_data[['lat', 'lon', 'trend_coef', 'trend_stderr', 'proj_distance', 'name']]
source['RLR9']['proj_distance'] /= 1000
source['RLR9']['dataset'] = 'RLR9'
source['RLR9']['trend_coef'] = np.nan
source['RLR9']['trend_stderr'] = np.nan
source['RLR9'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['RLR9']['name'], 'rlr'].values

source['Satellite'] = rlr_data[['lat', 'lon', 'proj_distance', 'name']]
source['Satellite']['proj_distance'] /= 1000
source['Satellite']['dataset'] = 'Satellite'
source['Satellite']['trend_coef'] = np.nan
source['Satellite']['trend_stderr'] = np.nan
source['Satellite'][['trend_coef', 'trend_stderr']] = trend_values.loc[source['Satellite']['name'], 'satellite'].values
    
for name, color in zip(names, colors):
    
    data = source[name]
    
    # Draw the sea level trend
    fig.line(dist/1000, data['trend_coef'].values, line_width=2, legend=name, color=color, alpha=0.5)
    fig.circle('proj_distance', 'trend_coef', size=7, color=color, alpha=0.5, source=source[name])
    
    # Fill between std err
    lower = data['trend_coef'].values - data['trend_stderr'].values
    upper = data['trend_coef'].values + data['trend_stderr'].values
    fig.patch(
        np.r_[dist, dist[::-1]]/1000, 
        np.r_[lower, upper[::-1]],
        color=color, 
        fill_alpha=0.2,
        line_alpha=0.0
    )

fig.legend.location = "top_left"
fig.yaxis.axis_label = 'Linear trend coefficient (mm/year)'
fig.xaxis.axis_label = 'Distance along coast'
bokeh.io.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eabcb9f9-3571-419a-842f-3a3297caa798"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eabcb9f9-3571-419a-842f-3a3297caa798");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eabcb9f9-3571-419a-842f-3a3297caa798");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eabcb9f9-3571-419a-842f-3a3297caa798' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8c71f723-72d2-4835-a75d-347e7635a2b5":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"proj_distance"},"y":{"field":"trend_coef"}},"id":"6101ed40-9362-465f-b932-3da6465f40a8","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDiheeF9CZWQFKOPFZu22JATJd7+Y8FakCuH98rdTZwQJNak0K+9XZAk1qTQr71dkCuH98rdTZwQEyXe/mPBWpAUo48Vm7bYkDiheeF9CZWQKjRgQoLDy5A","dtype":"float64","shape":[12]},"y":{"__ndarray__":"1XsvUzNvB0CjVQq4u+8DQCaJ+fGEJAFADGqkz+FP/T9wAGiMg6YNQJkddW7JTQlA0kKeC5iGFUBEbj/a2ukXQKbC/zJS5A1AvkwoWd0fD0CoQMtuYRcQQE7kFzDXOhFA","dtype":"float64","shape":[12]}}},"id":"2f34da8f-c4bc-4165-86e6-83b4f4a06b57","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"orange"},"line_alpha":{"value":0.5},"line_color":{"value":"orange"},"size":{"units":"screen","value":7},"x":{"field":"proj_distance"},"y":{"field":"trend_coef"}},"id":"98dc4a29-3e2d-410d-a560-513aaed70e99","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"302f0941-6fee-4e72-b37f-2d3b97e0866d","type":"Line"},{"attributes":{"below":[{"id":"28a8b554-a424-4847-b833-5e418fe7b77b","type":"LinearAxis"}],"left":[{"id":"97d2911e-0004-4205-9847-6dc54b1b7d5a","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"28a8b554-a424-4847-b833-5e418fe7b77b","type":"LinearAxis"},{"id":"942144e9-32a4-4206-aedd-f00813a5488f","type":"Grid"},{"id":"97d2911e-0004-4205-9847-6dc54b1b7d5a","type":"LinearAxis"},{"id":"d7a06f1c-959d-40ae-b372-99c430215532","type":"Grid"},{"id":"f0bcf607-01de-46ec-82e2-25ab213a1205","type":"BoxAnnotation"},{"id":"e617d51a-a65f-464b-8999-ca8432ef345f","type":"Legend"},{"id":"a77c58c2-766e-473a-ae6b-b91ed5e3193c","type":"GlyphRenderer"},{"id":"aa5b0fb2-bf2d-4bdd-99e4-d1a0c14a17f0","type":"GlyphRenderer"},{"id":"eb0267fc-4fb3-4893-91b8-eb1daedee961","type":"GlyphRenderer"},{"id":"82c7160b-04d6-4a9f-87b4-eac85f0ef24e","type":"GlyphRenderer"},{"id":"39e8abf1-1564-4d28-825f-343762e16949","type":"GlyphRenderer"},{"id":"4ce1ce93-1e93-4678-9f9b-3be1424c5ad5","type":"GlyphRenderer"}],"title":{"id":"1094e175-8723-4d22-92d1-8049e86f4914","type":"Title"},"tool_events":{"id":"e2563652-4f64-45fc-a203-67621670207d","type":"ToolEvents"},"toolbar":{"id":"f16f1cd1-5c94-4d40-b8b2-67919c9a7775","type":"Toolbar"},"x_range":{"id":"693119a1-1fef-488b-8aa6-b21277055bac","type":"DataRange1d"},"y_range":{"id":"f9af7ccb-721c-4c3b-85c0-2fcb87fe8a1b","type":"Range1d"}},"id":"5370ecf3-486d-4325-a634-51c51ad78e80","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"2f34da8f-c4bc-4165-86e6-83b4f4a06b57","type":"ColumnDataSource"},"glyph":{"id":"7a8135ad-a9f2-4daf-a3fa-343b6df00a37","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"641c2a82-264d-4111-99fc-eeadcf1e7ff4","type":"Patch"},"selection_glyph":null},"id":"eb0267fc-4fb3-4893-91b8-eb1daedee961","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5370ecf3-486d-4325-a634-51c51ad78e80","subtype":"Figure","type":"Plot"}},"id":"3263abbe-b676-411f-9632-c6f58c701950","type":"SaveTool"},{"attributes":{"callback":null,"plot":{"id":"5370ecf3-486d-4325-a634-51c51ad78e80","subtype":"Figure","type":"Plot"},"tooltips":[["station","@name"],["dataset","@dataset"],["(lon,lat)","(@lon, @lat)"],["coef","@trend_coef"],["stderr","@trend_stderr"]]},"id":"d25d6ebe-706d-4d79-ae07-18bb18b81822","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"qNGBCgsPLkDiheeF9CZWQFKOPFZu22JATJd7+Y8FakCuH98rdTZwQJNak0K+9XZA","dtype":"float64","shape":[6]},"y":{"__ndarray__":"OKKv2XDyDEB6a9BKPw8KQPLqkCUxIghA1vtojSFGBkA+tzlQjl4TQM9obGG+FhFA","dtype":"float64","shape":[6]}}},"id":" ...

# %% [markdown]
# The results from the satellite data match well with the results from the tidal stations. The 'zig-zag' differences are near mean filled NaN-values, so that could be a possible explaination for these differences. The standard errors have the some order of magnitude, however the standard error is somewhat larger in the Waddensea.
#
# The satellite data are a nice addition to the tidal station data, also because they span a large area, instead of a few point sources. This can help in identifying causes of regional sea level changes. A downside is the relatively short time series for which they are available. This results in a large spread, so the uncertainty around the 'actual' trend is large. This makes extrapolation to the near future (a useful application for practical purposes) tricky.

# %% [markdown]
# ## Conclusions
# In this notebook possible sources for obtaining more data for the sea level monitor where explored. These extra data can subsequently be used to get a better view on regional differences in the speed with which the sea level rises.
#
# First the extra tide gauges available from PSMSL where considered. Three extra stations, Maassluis, West-terschelling en Roompot Buiten, are available in the official rlr-dataset. The first two are located closely to other RLR-stations, while the last has only a short timeseries. Adding these stations to the sea level monitor thus provides not much added value.
#
# A second source of extra data is the metric dataset available on PSMSL. The data from this dataset are however from worse quality (which is also clearly communicated by PSMSL) than the rlr monthly data. This makes the dataset less useful for practical purposes.
#
# A last source of data is satellite data available though AVISO altimetry. These data coincide reasonably well with the tidal gauge data, and are available for the complete Northsea (and world), with an resolution of a quarter degree longitude and latitide. The data are however available from 1993 on, which gives a large uncertainty around the trend. This makes it difficult to use it for short term predictions. The availability across the whole North Sea makes it however a good source for finding or checking sources of sea level rise differences.
