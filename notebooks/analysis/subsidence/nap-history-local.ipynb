# %%
import io
import pathlib
import logging

import dateutil.parser
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
import matplotlib.cm
import seaborn

import pyproj
import requests
import rtree


# %matplotlib inline

# %% [markdown]
# The NAP history for a location
# ================
# In this notebook we examine the NAP history records that were collected for the leveling of the Dutch Ornance system.
# For the selected location we create a chart with all leveling measurements.

# %%
# reproject to other coordinate systems
# example, Oude Kerk in Naaldwijk

locations = [
    {
        "name": "Oude Kerk in Naaldwijk",
        "lat": 51.9928403,
        "lon": 4.2088293
    },
    {
        "name": "Protestatse Kerk in de Lier",
        "lat": 51.9742416,
        "lon": 4.247632
    },
    {
        "name": "Bartholomeus Kerk in Poeldijk",
        "lat": 52.0218379,
        "lon": 4.2202144
    },
    {
        "name": "Hervormde gemeente",
        "lat": 52.0217429,
        "lon": 4.1725854
    }
]



# We use pyproj
wgs84 = pyproj.Proj(init='epsg:4326')
rd = pyproj.Proj(init='epsg:28992')
etrs89_utm31n = pyproj.Proj(init='epsg:25831')

# compute coordinates in different coordinate systems
for location in locations:
    location['x_rd'], location['y_rd'] = pyproj.transform(
        wgs84, 
        rd, 
        location['lon'], 
        location['lat']
    )
    location['x_utm'], location['y_utm'] = pyproj.transform(
        wgs84, 
        etrs89_utm31n, 
        location['lon'],
        location['lat']
    )

locations
# Out:
# [{'name': 'Oude Kerk in Naaldwijk',
#   'lat': 51.9928403,
#   'lon': 4.2088293,
#   'x_rd': 74068.26605010244,
#   'y_rd': 445595.4466889998,
#   'x_utm': 582998.5460646378,
#   'y_utm': 5760931.8143537985},
#  {'name': 'Protestatse Kerk in de Lier',
#   'lat': 51.9742416,
#   'lon': 4.247632,
#   'x_rd': 76700.65707071386,
#   'y_rd': 443483.8630098191,
#   'x_utm': 585698.141053623,
#   'y_utm': 5758908.343206454},
#  {'name': 'Bartholomeus Kerk in Poeldijk',
#   'lat': 52.0218379,
#   'lon': 4.2202144,
#   'x_rd': 74901.98960993187,
#   'y_rd': 448808.74142180645,
#   'x_utm': 583726.085567847,
#   'y_utm': 5764169.895130395},
#  {'name': 'Hervormde gemeente',
#   'lat': 52.0217429,
#   'lon': 4.1725854,
#   'x_rd': 71632.93309604372,
#   'y_rd': 448851.7726034998,
#   'x_utm': 580458.2628416776,
#   'y_utm': 5764105.532261407}]

# %% [markdown]
# # NAP history
#
# This notebook analyses the history of the Dutch Ordnance Datum (NAP). This is an analysis of the unpublished history of the measurements of the NAP.
# The datasets are derived from different levellings and therefor not unambiguously interpretable. The quality of the measurements can vary and no information about the quality is present.
#
# The NAP was revised in 2005. The reference level was revised with several centimeters, varying over the Netherlands. The project-ID shows if a measurement was taken before or after the revision. Measurements after 2005 are from the revised level. Some projects have both a revised and unrevised data. Projects with an ‘=’ mark are relative to the revised level. For example:
# Project-ID  370W26 old NAP.
# Project-ID  370=26=NAP  same project in revised NAP.

# %%
# this is the file that was delivered by Rijkswaterstaat
# The file is a printed table, probably an extract from a database 
path = pathlib.Path('../../../data/rws/nap/historie/NAP_Historie.txt')
# open the file
stream = path.open()
# print the first few lines
print("".join(stream.readlines()[:5]))
# Out:
# +----------+-----------+-----------+----------+------------------------------------------------------------+-------------------------+-----------+
# |ID        |x          |y          |project_id|titel                                                       |datum                    |NAP hoogte |
# +----------+-----------+-----------+----------+------------------------------------------------------------+-------------------------+-----------+
# |000A1011  | 163880.630| 540553.300|279H04    |HYDRO SCHARNEGOUTUM                                         |01-may-1986              |      5.121|
# |000A1011  | 163880.630| 540553.300|332=04=NAP|SEC herziening 332w04 groningen friesland 1993              |28-jun-1993              |      5.122|

# %%
# because the table is not in a standardized format, we have some cleaning up to do
lines = []
for i, line in enumerate(path.open()):
    # split the first and third line (only dashes and +)
    if i in (0, 2):
        continue
    # strip the | and whitespace
    fields = line.split('|')
    # put all fields in a list and strip of reamining | 
    fields = [field.strip().strip('|') for field in fields]
    # remove first and last column (should be empty)
    assert fields[0] == '' and fields[-1] == ''
    fields = fields[1:-1]
    # rejoin with the | (some fields contain , and ;, so we separate by |)
    line = "|".join(fields)
    # keep a list
    lines.append(line)
# concatenate cleaned up fields
txt = "\n".join(lines)

# %%
# read the CSV file as a table
df = pd.read_csv(io.StringIO(txt), sep='|', dtype={
    'titel': str,
    'x': float,
    'y': float
})
# make sure all titles are strings (some floats)
df['titel'] = df['titel'].astype(str)
# convert dates to dates
# did not check if the date format is consistent (not a common date format), let the parser guess
df['date'] = df['datum'].apply(lambda x: dateutil.parser.parse(x))

# based on the instructions, everything with an equal sign or after 2005 should be the revised NAP
# TODO: check if NAP correction is consistent with correction in use by PSMSL to create a local tide gauge benchmark
def is_revised(row):
    if row['date'].year >= 2005:
        return True
    if '=' in row['project_id']:
        return True
    return False
df['revised'] = df.apply(is_revised, axis=1)

# %% [markdown]
# The NAP history records show the measurements of the benchmarks in reference to the NAP. Each measurement is done in the context of a project. These projects include the "Waterpassingingen", the countrywide levellings. These are abbreviated as "WP" in this dataset.

# %%
# show the first few records
df.head()
# Out:
#          ID          x         y  project_id  \
# 0  000A1011  163880.63  540553.3      279H04
# 1  000A1011  163880.63  540553.3  332=04=NAP
# 2  000A1011  163880.63  540553.3  330=01=NAP
# 3  000A1011  163880.63  540553.3      332W04
# 4  000A1011  163880.63  540553.3      PR3.57
#
#                                             titel        datum  NAP hoogte  \
# 0                             HYDRO SCHARNEGOUTUM  01-may-1986       5.121
# 1  SEC herziening 332w04 groningen friesland 1993  28-jun-1993       5.122
# 2        SEC herziening 330w01 noord holland 1991  27-feb-1991       5.122
# 3                             GRONINGEN+FRIESLAND  01-sep-1993       5.121
# 4                             3E NAUWK WP 1950-59  01-jan-1957       5.121
#
#         date  revised
# 0 1986-05-01    False
# 1 1993-06-28     True
# 2 1991-02-27     True
# 3 1993-09-01    False
# 4 1957-01-01    False

# %%
# Some records don't have a location. We can't use them, so we'll drop them out of the dataset
total_n = len(df)
missing_n = total_n - len(df.dropna())
assert missing_n == df['x'].isna().sum(), "we expected all missings to be missings without coordinates"
logging.warning("%s records are dropped from the %s records", missing_n, total_n)
             
df = df.dropna()
# Out:
# WARNING:root:4084 records are dropped from the 455784 records

# %% [markdown]
# NAP measurement locations
# ==============
# We have now read all the data points and cleaned up some unusable records. That leaves us with about 0.5 million measurements.  Here we plot the locations. This gives an idea of the distribution, where more dense areas are shown in darker green. Areas that are measured more often include Groningen, where there is more subsidence, due to gass extraction and Rotterdam.  Notice the triangles and quads that are used to connect the benchmarks.

# %%
fig, ax = plt.subplots(figsize=(10, 13))
ax.axis('equal')
ax.set_title('NAP benchmark history coverage')
ax.plot(df['x'], df['y'], 'g.', alpha=0.1, markersize=1, label='NAP measurement')
for location in locations:
    ax.plot(location['x_rd'], location['y_rd'], 'k.', label='location')
    ax.annotate(xy=[location['x_rd'], location['y_rd']], s=location['name'])
ax.set_xlabel('x [m] EPSG:28992')
ax.set_ylabel('y [m] EPSG:28992')
ax.legend(loc='best');

# %% [markdown]
# Benchmarks close to location
# =================
#
# Here we'll create an r-tree index to quickly lookup benchmarks near the location. We'll extract the benchmark locations. Create an index. Use that index to find benchmarks near the location and then filter by distance.
#
# For each benchmark we compute a 0 reference. This is the benchmark height when it was first measured. This allows us to focus on the subsidence of each benchmark.

# %%
# create a list of all NAP marks
grouped = df.groupby('ID')
nap_marks = grouped.agg('first')[['x', 'y']]
nap_marks.head()
# Out:
#                   x          y
# ID
# 000A1011  163880.63  540553.30
# 000A1012  163906.00  540538.00
# 000A1013  163890.00  540512.00
# 000A1014  163864.65  540527.95
# 000A1015  163882.00  540553.53

# %%
# create a rtree to be able to quickly lookup nearest points
index = rtree.Rtree(
    (i, tuple(row) + tuple(row), obj)
    for i, (obj, row)
    in enumerate(nap_marks.iterrows())
)

# %%
# here we'll create a list of records that are close to our tide gauges
closest_dfs = []
for location in locations:
    # benchmarks near our current station
    nearest_ids = list(
        item.object
        for item 
        in index.nearest(
            (location['x_rd'], location['y_rd']), 
            # TODO: check why we use 10000. Are the benchmarks grouped?
            num_results=10000, 
            objects=True
        )
    )
    # lookup corresponding records
    closest = df[np.in1d(df.ID, nearest_ids)].copy()
    # compute the distance
    closest['distance'] = np.sqrt((location['x_rd'] - closest['x'])**2 + (location['y_rd'] - closest['y'])**2)
    # set the station
    closest['name'] = location['name']
    # drop all records further than 3km
    # you might want to use a more geological sound approach here, taking into account  faults, etc...
    closest = closest[closest['distance'] <= 1000]
    # sort
    closest = closest.sort_values(by=['name', 'ID', 'date'])
    # loop over each mark to add the 0 reference
    # the 0 reference is the height of the benchmark when it was first measured
    for it, df_group in iter(closest.groupby(('ID', 'x', 'y'))):
        df_group = df_group.copy()
        # add the 0 first height
        hoogtes = df_group['NAP hoogte']
        hoogtes_0 = hoogtes - hoogtes.iloc[0]
        df_group['hoogtes_0'] = hoogtes_0
        closest_dfs.append(df_group)

# %%
# combine all the selected records
selected = pd.concat(closest_dfs)
# problem with plotting dates correctly in seaborn, so we'll just use numbers
selected['year'] = selected['date'].apply(lambda x: x.year + x.dayofyear/366.0)

# %%
# show the number of measurements for each tide gauge
selected.groupby('name').agg('count')[['ID']]
# Out:
#                                 ID
# name
# Bartholomeus Kerk in Poeldijk   44
# Hervormde gemeente             188
# Oude Kerk in Naaldwijk         245
# Protestatse Kerk in de Lier    200

# %% [markdown]
# Subsidence estimates per location
# ============
#
# The following figure shows the changes of all the benchmarks that are close to a location, in a subfigure of the nearby location. Not all the benchmarks have been measured since the same time and not all benchmarks are measured relative to the same ordnance level. We can compare the trend of all the lines that are plotted.

# %%
palette = seaborn.palettes.cubehelix_palette(reverse=True)
cmap = seaborn.palettes.cubehelix_palette(reverse=True, as_cmap=True)
grid = seaborn.FacetGrid(selected, col="name", hue="distance", col_wrap=3, palette=palette, size=5)
grid.map(plt.plot, "year", "hoogtes_0", marker="o", ms=4, alpha=0.3)
grid.set(ylim=(-0.5, 0.1))
grid.set_ylabels('Height [m] related to 0 reference')
grid.set_xlabels('Time');
cbar_ax = grid.fig.add_axes([1.01, .3, .02, .4])  # <-- Create a colorbar axes
cb = matplotlib.colorbar.ColorbarBase(
    cbar_ax, 
    cmap=cmap,
    norm=matplotlib.colors.Normalize(0, 3000),
    orientation='vertical'
)

# %%
selected
# Out:
#               ID        x         y  project_id  \
# 273867  037B0045  73780.0  444660.0  310101-1-1
# 273882  037B0045  73780.0  444660.0      PR2.31
# 273870  037B0045  73780.0  444660.0  560101-2-1
# 273878  037B0045  73780.0  444660.0      157W01
# 273879  037B0045  73780.0  444660.0      157W02
# 273880  037B0045  73780.0  444660.0      157W03
# 273885  037B0045  73780.0  444660.0      157W04
# 273881  037B0045  73780.0  444660.0      157W05
# 273877  037B0045  73780.0  444660.0         200
# 273876  037B0045  73780.0  444660.0      214W29
# 273887  037B0045  73780.0  444660.0      270W10
# 273875  037B0045  73780.0  444660.0      249W42
# 273874  037B0045  73780.0  444660.0  289=27=NAP
# 273886  037B0045  73780.0  444660.0      289W27
# 273865  037B0045  73780.0  444660.0      317W00
# 273866  037B0045  73780.0  444660.0  317=00=NAP
# 273868  037B0045  73780.0  444660.0  332=03=NAP
# 273869  037B0045  73780.0  444660.0      332W03
# 273883  037B0045  73780.0  444660.0  342=07=NAP
# 273884  037B0045  73780.0  444660.0      342W07
# 273873  037B0045  73780.0  444660.0  363W00-SEC
# 273872  037B0045  73780.0  444660.0  363=00=NAP
# 273890  037B0045  73780.0  444660.0  363W00HSEC
# 273864  037B0045  73780.0  444660.0  376W49-SEC
# 273889  037B0045  73780.0  444660.0  376=49=NAP
# 273863  037B0045  73780.0  444660.0      380=82
# 273862  037B0045  73780.0  444660.0      384=04
# 273888  037B0045  73780.0  444660.0     386=063
# 273871  037B0045  73780.0  444660.0     386=144
# 274020  037B0052  73300.0  445190.0  560101-2-1
# ...          ...      ...       ...         ...
# 276290  037B0239  71390.0  449210.0      289W27
# 276302  037B0239  71390.0  449210.0  289=27=NAP
# 276294  037B0239  71390.0  449210.0  332=03=NAP
# 276295  037B0239  71390.0  449210.0      332W03
# 276298  037B0239  71390.0  449210.0  342=07=NAP
# 276299  037B0239  71390.0  449210.0      342W07
# 276300  037B0239  71390.0  449210.0  363W00-SEC
# 276291  037B0239  71390.0  449210.0  363W00HSEC
# 276301  037B0239  71390.0  449210.0  363=00=NAP
# 276292  037B0239  71390.0  449210.0  376W49-SEC
# 276296  037B0239  71390.0  449210.0  376=49=NAP
# 276293  037B0239  71390.0  449210.0      380=82
# 276297  037B0239  71390.0  449210.0      384=04
# 276304  037B0239  71390.0  449210.0     386=063
# 276305  037B0239  71390.0  449210.0     386=077
# 276303  037B0239  71390.0  449210.0     386=144
# 276306  037B0239  71390.0  449210.0      388=01
# 276885  037B0289  71740.0  449280.0      371W00
# 276886  037B0289  71740.0  449280.0  371=00=NAP
# 277112  037B0352  70730.0  448570.0     386=063
# 277111  037B0352  70730.0  448570.0     386=077
# 277162  037B0820  71730.0  449710.0     386=077
# 277163  037B0820  71730.0  449710.0      388=01
# 277164  037B0821  72080.0  449540.0     386=077
# 277165  037B0821  72080.0  449540.0      388=01
# 277166  037B0822  72090.0  449110.0     386=077
# 277167  037B0823  71060.0  449040.0     386=077
# 277168  037B0824  71460.0  448490.0     386=077
# 277218  037B0864  70730.0  448570.0     386=144
# 277219  037B0864  70730.0  448570.0      388=01
#
#                                                     titel        datum  \
# 273867                                                nan  01-jan-1931
# 273882                               2E NAUWK. WP 1926-40  01-jan-1931
# 273870                                                nan  01-jan-1956
# 273878                                       CONC DE LIER  01-jan-1956
# 273879                                       CONC DE LIER  01-jan-1958
# 273880                                       CONC DE LIER  01-jan-1961
# 273885                                       CONC DE LIER  01-jan-1965
# 273881                                       CONC DE LIER  01-jan-1972
# 273877                               UITB 78 ZUID HOLLAND  01-mar-1978
# 273876                                       CONC DE LIER  01-jan-1979
# 273887                                TERT Z-HOLLAND 1978  01-jan-1979
# 273875                                       CONC DE LIER  15-jun-1984
# 273874                                   CON de lier 1991  31-jan-1989
# 273886                                  CONSESSIE DE LIER  31-jan-1989
# 273865                                SEC WP ZUID-HOLLAND  01-nov-1989
# 273866           SEC herziening 317w00  zuid holland 1989  12-nov-1989
# 273868                          CON de lier - botlek 1992  05-oct-1992
# 273869                               NAM-DE LIER-BOTLEK/P  15-oct-1992
# 273883                                  CON westland 1995  06-oct-1995
# 273884  Nauwkeurigheidswaterpassing NAM, Rotterdam/Wes...  06-oct-1995
# 273873         riv west deel a   werknr 11354A  1998/1999  07-mar-1999
# 273872  SEC herziening 363w00hsec+363w01-sec rivieren-...  09-mar-1999
# 273890  herberekening 363w00+363w01 +3 overg + opt tra...  09-mar-1999
# 273864                   concessie HvH 2002 (de Lier enz)  08-sep-2002
# 273889                  CON hoek van holland,de lier enz.  08-sep-2002
# 273863                 CON concessie zuidholland 2005 NAM  24-nov-2005
# 273862       SEC Zuid-Holland (RWS + NAM) en Zeeland 2008  02-sep-2008
# 273888                          CON zuid-holland 2011 NAM  07-jul-2011
# 273871                          CON Zuid Holland 2014 NAM  23-sep-2014
# 274020                                                nan  01-jan-1956
# ...                                                   ...          ...
# 276290                                  CONSESSIE DE LIER  31-jan-1989
# 276302                                   CON de lier 1991  31-jan-1989
# 276294                          CON de lier - botlek 1992  05-oct-1992
# 276295                               NAM-DE LIER-BOTLEK/P  15-oct-1992
# 276298                                  CON westland 1995  06-oct-1995
# 276299  Nauwkeurigheidswaterpassing NAM, Rotterdam/Wes...  06-oct-1995
# 276300         riv west deel a   werknr 11354A  1998/1999  07-mar-1999
# 276291  herberekening 363w00+363w01 +3 overg + opt tra...  09-mar-1999
# 276301  SEC herziening 363w00hsec+363w01-sec rivieren-...  09-mar-1999
# 276292                   concessie HvH 2002 (de Lier enz)  08-sep-2002
# 276296                  CON hoek van holland,de lier enz.  08-sep-2002
# 276293                 CON concessie zuidholland 2005 NAM  24-nov-2005
# 276297       SEC Zuid-Holland (RWS + NAM) en Zeeland 2008  02-sep-2008
# 276304                          CON zuid-holland 2011 NAM  07-jul-2011
# 276305                              GEM gemeente Westland  04-jan-2012
# 276303                          CON Zuid Holland 2014 NAM  23-sep-2014
# 276306                              SEC Zuid-Holland 2016  09-jul-2016
# 276885                           5E PRIMAIRE WATERPASSING  20-mar-1997
# 276886          PRI prim 5 herziening 371w00 - MAART 1997  23-mar-1997
# 277112                          CON zuid-holland 2011 NAM  07-jul-2011
# 277111                              GEM gemeente Westland  04-jan-2012
# 277162                              GEM gemeente Westland  04-jan-2012
# 277163                              SEC Zuid-Holland 2016  09-jul-2016
# 277164                              GEM gemeente Westland  04-jan-2012
# 277165                              SEC Zuid-Holland 2016  09-jul-2016
# 277166                              GEM gemeente Westland  04-jan-2012
# 277167                              GEM gemeente Westland  04-jan-2012
# 277168                              GEM gemeente Westland  04-jan-2012
# 277218                          CON Zuid Holland 2014 NAM  23-sep-2014
# 277219                              SEC Zuid-Holland 2016  09-jul-2016
#
#         NAP hoogte       date  revised    distance                    name  \
# 273867       2.002 1931-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273882       1.980 1931-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273870       1.978 1956-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273878       1.980 1956-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273879       1.976 1958-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273880       1.973 1961-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273885       1.969 1965-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273881       1.933 1972-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273877       1.927 1978-03-01    False  978.855364  Oude Kerk in Naaldwijk
# 273876       1.924 1979-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273887       1.927 1979-01-01    False  978.855364  Oude Kerk in Naaldwijk
# 273875       1.912 1984-06-15    False  978.855364  Oude Kerk in Naaldwijk
# 273874       1.878 1989-01-31     True  978.855364  Oude Kerk in Naaldwijk
# 273886       1.899 1989-01-31    False  978.855364  Oude Kerk in Naaldwijk
# 273865       1.897 1989-11-01    False  978.855364  Oude Kerk in Naaldwijk
# 273866       1.875 1989-11-12     True  978.855364  Oude Kerk in Naaldwijk
# 273868       1.872 1992-10-05     True  978.855364  Oude Kerk in Naaldwijk
# 273869       1.893 1992-10-15    False  978.855364  Oude Kerk in Naaldwijk
# 273883       1.866 1995-10-06     True  978.855364  Oude Kerk in Naaldwijk
# 273884       1.888 1995-10-06    False  978.855364  Oude Kerk in Naaldwijk
# 273873       1.883 1999-03-07    False  978.855364  Oude Kerk in Naaldwijk
# 273872       1.861 1999-03-09     True  978.855364  Oude Kerk in Naaldwijk
# 273890       1.883 1999-03-09    False  978.855364  Oude Kerk in Naaldwijk
# 273864       1.875 2002-09-08    False  978.855364  Oude Kerk in Naaldwijk
# 273889       1.852 2002-09-08     True  978.855364  Oude Kerk in Naaldwijk
# 273863       1.850 2005-11-24     True  978.855364  Oude Kerk in Naaldwijk
# 273862       1.844 2008-09-02     True  978.855364  Oude Kerk in Naaldwijk
# 273888       1.837 2011-07-07     True  978.855364  Oude Kerk in Naaldwijk
# 273871       1.834 2014-09-23     True  978.855364  Oude Kerk in Naaldwijk
# 274020       2.347 1956-01-01    False  868.688518  Oude Kerk in Naaldwijk
# ...            ...        ...      ...         ...                     ...
# 276290       3.112 1989-01-31    False  432.831788      Hervormde gemeente
# 276302       3.092 1989-01-31     True  432.831788      Hervormde gemeente
# 276294       3.092 1992-10-05     True  432.831788      Hervormde gemeente
# 276295       3.113 1992-10-15    False  432.831788      Hervormde gemeente
# 276298       3.087 1995-10-06     True  432.831788      Hervormde gemeente
# 276299       3.108 1995-10-06    False  432.831788      Hervormde gemeente
# 276300       3.103 1999-03-07    False  432.831788      Hervormde gemeente
# 276291       3.103 1999-03-09    False  432.831788      Hervormde gemeente
# 276301       3.083 1999-03-09     True  432.831788      Hervormde gemeente
# 276292       3.104 2002-09-08    False  432.831788      Hervormde gemeente
# 276296       3.082 2002-09-08     True  432.831788      Hervormde gemeente
# 276293       3.078 2005-11-24     True  432.831788      Hervormde gemeente
# 276297       3.073 2008-09-02     True  432.831788      Hervormde gemeente
# 276304       3.072 2011-07-07     True  432.831788      Hervormde gemeente
# 276305       3.072 2012-01-04     True  432.831788      Hervormde gemeente
# 276303       3.067 2014-09-23     True  432.831788      Hervormde gemeente
# 276306       3.060 2016-07-09     True  432.831788      Hervormde gemeente
# 276885       1.277 1997-03-20    False  441.409136      Hervormde gemeente
# 276886       1.256 1997-03-23     True  441.409136      Hervormde gemeente
# 277112       2.268 2011-07-07     True  945.877358      Hervormde gemeente
# 277111       2.268 2012-01-04     True  945.877358      Hervormde gemeente
# 277162       2.773 2012-01-04     True  863.699165      Hervormde gemeente
# 277163       2.760 2016-07-09     True  863.699165      Hervormde gemeente
# 277164       1.144 2012-01-04     True  820.686156      Hervormde gemeente
# 277165       1.135 2016-07-09     True  820.686156      Hervormde gemeente
# 277166       1.126 2012-01-04     True  524.968135      Hervormde gemeente
# 277167       1.534 2012-01-04     True  603.060433      Hervormde gemeente
# 277168       1.648 2012-01-04     True  400.980389      Hervormde gemeente
# 277218       1.956 2014-09-23     True  945.877358      Hervormde gemeente
# 277219       1.950 2016-07-09     True  945.877358      Hervormde gemeente
#
#         hoogtes_0         year
# 273867      0.000  1931.002732
# 273882     -0.022  1931.002732
# 273870     -0.024  1956.002732
# 273878     -0.022  1956.002732
# 273879     -0.026  1958.002732
# 273880     -0.029  1961.002732
# 273885     -0.033  1965.002732
# 273881     -0.069  1972.002732
# 273877     -0.075  1978.163934
# 273876     -0.078  1979.002732
# 273887     -0.075  1979.002732
# 273875     -0.090  1984.456284
# 273874     -0.124  1989.084699
# 273886     -0.103  1989.084699
# 273865     -0.105  1989.833333
# 273866     -0.127  1989.863388
# 273868     -0.130  1992.762295
# 273869     -0.109  1992.789617
# 273883     -0.136  1995.762295
# 273884     -0.114  1995.762295
# 273873     -0.119  1999.180328
# 273872     -0.141  1999.185792
# 273890     -0.119  1999.185792
# 273864     -0.127  2002.685792
# 273889     -0.150  2002.685792
# 273863     -0.152  2005.896175
# 273862     -0.158  2008.672131
# 273888     -0.165  2011.513661
# 273871     -0.168  2014.726776
# 274020      0.000  1956.002732
# ...           ...          ...
# 276290      0.000  1989.084699
# 276302     -0.020  1989.084699
# 276294     -0.020  1992.762295
# 276295      0.001  1992.789617
# 276298     -0.025  1995.762295
# 276299     -0.004  1995.762295
# 276300     -0.009  1999.180328
# 276291     -0.009  1999.185792
# 276301     -0.029  1999.185792
# 276292     -0.008  2002.685792
# 276296     -0.030  2002.685792
# 276293     -0.034  2005.896175
# 276297     -0.039  2008.672131
# 276304     -0.040  2011.513661
# 276305     -0.040  2012.010929
# 276303     -0.045  2014.726776
# 276306     -0.052  2016.521858
# 276885      0.000  1997.215847
# 276886     -0.021  1997.224044
# 277112      0.000  2011.513661
# 277111      0.000  2012.010929
# 277162      0.000  2012.010929
# 277163     -0.013  2016.521858
# 277164      0.000  2012.010929
# 277165     -0.009  2016.521858
# 277166      0.000  2012.010929
# 277167      0.000  2012.010929
# 277168      0.000  2012.010929
# 277218      0.000  2014.726776
# 277219     -0.006  2016.521858
#
# [677 rows x 13 columns]
